# %% [markdown]
# <b><h4>HW3 - Notebook: Multi-Layer perceptron</h4></b>
#
# [CE40477: Machine Learning](https://www.sharifml.ir/)
#
# __Course Instructor__: Dr. Sharifi-Zarchi
#
# __Notebook Authors__: Amir Ezzati & Ali Bavafa
#
# Name:         yashar paymai
# Student-ID:   401100325

# %% [markdown]
# # Import & Helper Functions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import gdown
from sklearn.datasets import fetch_openml
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import time
import random

import torch
import torch.nn as nn
import torch.optim as optim

from torchvision import transforms
from torchvision.utils import make_grid
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, TensorDataset

from tqdm.auto import tqdm
from IPython.display import display

# %%
def seed_setter(seed=None, seed_torch=True):
  """
  Function that controls randomness.

  Args:
    seed : Integer
      A non-negative integer that defines the random state.
    seed_torch : Boolean
      If `True` sets the random seed for pytorch tensors.

  Returns:
    Nothing.
  """
  if seed is None:
    seed = np.random.choice(2 ** 32)
  random.seed(seed)
  np.random.seed(seed)
  if seed_torch:
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

  print(f'Random seed {seed} has been set.')


# In case that `DataLoader` is used
def seed_worker(worker_id):

  worker_seed = torch.initial_seed() % 2**32
  np.random.seed(worker_seed)
  random.seed(worker_seed)



def train_test_classification(net, criterion, optimizer, train_loader,
                              test_loader, num_epochs=1, verbose=True,
                              training_plot=False):
  """
  Accumulate training loss/Evaluate performance

  Args:
    net: Instance of Net class
      Describes the model with ReLU activation, batch size 128
    criterion: torch.nn type
      Criterion combines LogSoftmax and NLLLoss in one single class.
    optimizer: torch.optim type
      Implements Adam algorithm.
    train_loader: torch.utils.data type
      Combines the train dataset and sampler, and provides an iterable over the given dataset.
    test_loader: torch.utils.data type
      Combines the test dataset and sampler, and provides an iterable over the given dataset.
    num_epochs: int
      Number of epochs [default: 1]
    verbose: boolean
      If True, print statistics
    training_plot=False
      If True, display training plot

  Returns:
    Nothing
  """
  net.train()
  train_losses = []
  for epoch in tqdm(range(num_epochs)):
    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
      # Get the inputs; data is a list of [inputs, labels]
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      optimizer.zero_grad()
      outputs = net(inputs)

      loss = criterion(outputs, labels)
      loss.backward()
      optimizer.step()

      if verbose:
        train_losses += [loss.item()]

  net.eval()

  def test(data_loader):
    """
    Function to gauge network performance

    Args:
      data_loader: torch.utils.data type
        Combines the test dataset and sampler, and provides an iterable over the given dataset.

    Returns:
      acc: float
        Performance of the network
      total: int
        Number of datapoints in the dataloader
    """
    correct = 0
    total = 0
    for data in data_loader:
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      outputs = net(inputs)
      _, predicted = torch.max(outputs, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()

    acc = 100 * correct / total
    return total, acc

  train_total, train_acc = test(train_loader)
  test_total, test_acc = test(test_loader)

  if verbose:
    print(f'\nAccuracy on the {train_total} training samples: {train_acc:0.2f}')
    print(f'Accuracy on the {test_total} testing samples: {test_acc:0.2f}\n')

  if training_plot:
    plt.plot(train_losses)
    plt.xlabel('Batch')
    plt.ylabel('Training loss')
    plt.show()

  return train_acc, test_acc


def shuffle_and_split_data(X, y, seed):
  """
  Helper function to shuffle and split data

  Args:
    X: torch.tensor
      Input data
    y: torch.tensor
      Corresponding target variables
    seed: int
      Set seed for reproducibility

  Returns:
    X_test: torch.tensor
      Test data [20% of X]
    y_test: torch.tensor
      Labels corresponding to above mentioned test data
    X_train: torch.tensor
      Train data [80% of X]
    y_train: torch.tensor
      Labels corresponding to above mentioned train data
  """
  # Set seed for reproducibility
  torch.manual_seed(seed)
  # Number of samples
  N = X.shape[0]
  # Shuffle data
  shuffled_indices = torch.randperm(N)
  X = X[shuffled_indices]
  y = y[shuffled_indices]

  test_size = int(0.2 * N)
  X_test = X[:test_size]
  y_test = y[:test_size]
  X_train = X[test_size:]
  y_train = y[test_size:]

  return X_test, y_test, X_train, y_train


def sample_grid(M=500, x_max=2.0):
  """
  Helper function to simulate sample meshgrid

  Args:
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points

  Returns:
    X_all: torch.tensor
      Concatenated meshgrid tensor
  """
  ii, jj = torch.meshgrid(torch.linspace(-x_max, x_max,M),
                          torch.linspace(-x_max, x_max, M),
                          indexing='ij')
  X_all = torch.cat([ii.unsqueeze(-1),
                     jj.unsqueeze(-1)],
                     dim=-1).view(-1, 2)
  return X_all


def plot_decision_map(X_all, y_pred, X_test, y_test,
                      M=500, x_max=2.0, eps=1e-3):
  """
  Helper function to plot decision map

  Args:
    X_all: torch.tensor
      Concatenated meshgrid tensor
    y_pred: torch.tensor
      Labels predicted by the network
    X_test: torch.tensor
      Test data
    y_test: torch.tensor
      Labels of the test data
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points
    eps: float
      Decision threshold

  Returns:
    Nothing
  """
  decision_map = torch.argmax(y_pred, dim=1)

  for i in range(len(X_test)):
    indeces = (X_all[:, 0] - X_test[i, 0])**2 + (X_all[:, 1] - X_test[i, 1])**2 < eps
    decision_map[indeces] = (K + y_test[i]).long()

  decision_map = decision_map.view(M, M).cpu()
  plt.imshow(decision_map, extent=[-x_max, x_max, -x_max, x_max], cmap='jet')
  plt.axis('off')
  plt.plot()


def plot_function_apx(x_vals, relu_activations, predicted_output):
    """
    Visualizes ReLU activations and the resulting function approximation.

    Args:
      x_vals: torch.tensor
        Input x-axis data points.
      relu_activations: torch.tensor
        Calculated ReLU activations along x-axis for each ReLU unit.
      predicted_output: torch.tensor
        Estimated output labels or function approximations (weighted sum of ReLUs).

    Returns:
      None
    """

    fig, axes = plt.subplots(2, 1, figsize=(8, 6))

    ## Plot ReLU activations
    axes[0].plot(x_vals, relu_activations.T)
    axes[0].set_xlabel('x-values', fontsize=12)
    axes[0].set_ylabel('Activation Levels', fontsize=12)
    axes[0].set_title('ReLU Activations (Basis Functions)', fontsize=14)
    relu_labels = [f"ReLU {i + 1}" for i in range(relu_activations.shape[0])]
    axes[0].legend(relu_labels, ncol=2)

    ## Plot the function approximation and the ground truth
    axes[1].plot(x_vals, torch.sin(x_vals), label='Ground Truth (sin(x))', color='g', linewidth=2)
    axes[1].plot(x_vals, predicted_output, label='Predicted Output', linestyle='--', color='r')
    axes[1].set_xlabel('x-values', fontsize=12)
    axes[1].set_ylabel('y(x)', fontsize=12)
    axes[1].set_title('Function Approximation vs Ground Truth', fontsize=14)
    axes[1].legend()

    plt.tight_layout(pad=2)
    plt.show()


def show_images(image, num_row=2, num_col=5):
    # plot images
    image_size = int(np.sqrt(image.shape[-1]))
    image = np.reshape(image, (image.shape[0], image_size, image_size))
    fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*num_col,2*num_row))
    for i in range(num_row*num_col):
        ax = axes[i//num_col, i%num_col]
        ax.imshow(image[i], cmap='gray', vmin=0, vmax=1)
        ax.axis('off')
    plt.tight_layout()
    plt.show()


SEED = 2024
# Call `seed_setter` to ensure reproducibility.
seed_setter(seed=SEED)
# Out:
# Random seed 2024 has been set.

# %% [markdown]
# # Loading the data

# %%
# Load data
mnist_data = fetch_openml("mnist_784")
x = mnist_data["data"].astype('float').to_numpy()
y = mnist_data["target"].astype('int')

# Normalize
x /= 255.0

# One-hot encode labels
num_labels = len(np.unique(y))
y_new = to_categorical(y, num_labels)

# ---------------------------------------------------------------------
# In this section, split the data into training and test datasets, using 60,000 samples for training and the remaining samples for testing.

x_train, x_test, y_train, y_test = train_test_split(x, y_new, train_size=60000, random_state=SEED)

# --------------------------------------------------------------------

# %%
print("Training data: {} {}".format(x_train.shape, y_train.shape))
print("Test data: {} {}".format(x_test.shape, y_test.shape))
show_images(x_train)
# Out:
# Training data: (60000, 784) (60000, 10)
# Test data: (10000, 784) (10000, 10)

# %% [markdown]
# # Activation Functions & Optimizers

# %% [markdown]
# There are many activation functions which some of them listed below. In this section you should implement them.
#
# 1. Sigmoid:
# $$
# \operatorname{sigmoid}(x) = \frac{1}{1 + \exp(-x)}
# $$
#
# 2. Softmax: $$\operatorname{softmax}(\mathbf X)_{ij} = \frac{\exp(\mathbf X_{ij})}{\sum_k \exp \mathbf X_{ik})}.$$
#
#
# 3. Tanh (Hyperbolic Tangent):
# $$
# \operatorname{tanh}(x) = \frac{\sinh(x)}{\cosh(x)} = \frac{\exp(x) - \exp(-x)}{\exp(x) + \exp(-x)}
# $$
#
# 4. ReLU: $$\operatorname{ReLU}(x) = \max(0, x)$$
#
# 5. Leaky ReLU:
# $$
# \operatorname{LeakyReLU}(x) =
# \begin{cases}
# x & \text{if } x \geq 0 \\
# \alpha x & \text{if } x < 0
# \end{cases}
# $$
# where \( $\alpha$ \) is a small constant (e.g., 0.01).
#
# 6. ELU (Exponential Linear Unit):
# $$
# \operatorname{ELU}(x) =
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where ($\alpha$) is a positive constant.
#
# 7. SELU (Scaled Exponential Linear Unit):
# $$
# \operatorname{SELU}(x) =
# \lambda
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where \( $\lambda$ \) and \( $\alpha$ \) are predefined constants, typically \( $\lambda \approx 1.0507$ \) and \( $\alpha \approx 1.67326$ \).

# %% [markdown]
# ------
# There are several optimizer algorithms for optimizing the neural network over epochs. You should implement some of those mentioned in this section:
#
# ***Stochastic Gradient Descent (SGD)***
#
# SGD is the basic form of gradient descent, where each weight (\( w \)) and bias (\( b \)) parameter is updated in the opposite direction of its gradient.
#
# **Update Rule:**
# $$
# w^{(t+1)} = w^{(t)} - \eta \cdot \nabla_w L(w^{(t)}, b^{(t)})
# $$
# $$
# b^{(t+1)} = b^{(t)} - \eta \cdot \nabla_b L(w^{(t)}, b^{(t)})
# $$
#
# - \( w \): Weight parameters
# - \( b \): Bias parameters
# - \( $\eta$ \): Learning rate
# - \( $\nabla_w L(w, b)$ \): Gradient of the loss with respect to \( w \)
# - \( $\nabla_b L(w, b)$ \): Gradient of the loss with respect to \( b \)
#
# <br><br>
#
# ***Momentum Optimizer***
#
# Momentum optimizer smooths parameter updates by adding a velocity term to accumulate past gradients.
#
# **Update Rule:**
# 1. **Velocity Update for Weights and Biases:**
#    $$
#    v_w^{(t+1)} = \beta \cdot v_w^{(t)} + (1 - \beta) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_b^{(t+1)} = \beta \cdot v_b^{(t)} + (1 - \beta) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#
# 2. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot v_w^{(t+1)}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot v_b^{(t+1)}
#    $$
#
# - \( $v_w$ \): Velocity term for weights
# - \( $v_b$ \): Velocity term for biases
# - \( $\beta$ \): Momentum term, typically set to 0.9
#
# <br><br>
#
# ***Adam Optimizer***
#
# Adam combines momentum and adaptive learning rates, using both first (momentum) and second (RMSprop) moment estimates.
#
# **Update Rule:**
# 1. **Compute biased first and second moment estimates:**
#    $$
#    m_w^{(t+1)} = \beta_1 \cdot m_w^{(t)} + (1 - \beta_1) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    m_b^{(t+1)} = \beta_1 \cdot m_b^{(t)} + (1 - \beta_1) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_w^{(t+1)} = \beta_2 \cdot v_w^{(t)} + (1 - \beta_2) \cdot \left( \nabla_w L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#    $$
#    v_b^{(t+1)} = \beta_2 \cdot v_b^{(t)} + (1 - \beta_2) \cdot \left( \nabla_b L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#
# 2. **Compute bias-corrected estimates:**
#    $$
#    \hat{m}_w^{(t+1)} = \frac{m_w^{(t+1)}}{1 - \beta_1^{t+1}}, \quad \hat{m}_b^{(t+1)} = \frac{m_b^{(t+1)}}{1 - \beta_1^{t+1}}
#    $$
#    $$
#    \hat{v}_w^{(t+1)} = \frac{v_w^{(t+1)}}{1 - \beta_2^{t+1}}, \quad \hat{v}_b^{(t+1)} = \frac{v_b^{(t+1)}}{1 - \beta_2^{t+1}}
#    $$
#
# 3. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot \frac{\hat{m}_w^{(t+1)}}{\sqrt{\hat{v}_w^{(t+1)}} + \epsilon}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot \frac{\hat{m}_b^{(t+1)}}{\sqrt{\hat{v}_b^{(t+1)}} + \epsilon}
#    $$
#
# - \( $m_w$ \), \( $m_b$ \): First moment estimates (mean of gradients) for weights and biases
# - \( $v_w$ \), \( $v_b$ \): Second moment estimates (uncentered variance of gradients) for weights and biases
# - \( $\beta_1$ \): Decay rate for first moment, typically 0.9
# - \( $\beta_2$ \): Decay rate for second moment, typically 0.999
# - \( $\epsilon$ \): Small constant for numerical stability (e.g., \(10^{-8}\))

# %% [markdown]
# # MLP from Scratch

# %%
class MLP():
    def __init__(self, sizes, activation='sigmoid'):
        self.sizes = sizes
        self.num_layers = len(sizes) - 1  # number of layers excluding input
        self.activation_name = activation

        # Choose activation function
        if activation == 'relu':
            self.activation = self.relu
        elif activation == 'sigmoid':
            self.activation = self.sigmoid
        elif activation == 'tanh':
            self.activation = self.tanh
        # ---------------------------------------------------------------------
        elif activation == 'leaky_relu':
            self.activation = self.leaky_relu
        elif activation == 'elu':
            self.activation = self.elu
        elif activation == 'selu':
            self.activation = self.selu
        # ---------------------------------------------------------------------
        else:
            raise ValueError("This activation function is currently not supported!")

        # Save all weights
        self.params = self.initialize()
        # Save all intermediate values, i.e. activations
        self.cache = {}

    # Activation functions remain the same as defined in your original code
    def relu(self, x, derivative=False):
        '''
            Forward path:
            relu(x) = max(0, x)
            In other word,
            relu(x) = 0, if x < 0
                    = x, if x >= 0

            Backward path:
            ∇relu(x) = 0, if x < 0
                     = 1, if x >=0
        '''
        # ---------------------------------------------------------------------
        if derivative:
            return np.where(x <= 0, 0, 1)
        else:
            return np.maximum(0, x)
        # ---------------------------------------------------------------------

    def tanh(self, x, derivative=False):
        '''
            Forward path:
            tanh(x) = (exp(x) - exp(-x)) / (exp(x) + exp(-x))

            Backward path:
            ∇tanh(x) = 1 - tanh(x)^2
        '''
        # ---------------------------------------------------------------------
        if derivative:
            return 1 - np.tanh(x) ** 2
        else:
            return np.tanh(x)
        # --------------------------------------------------------------------

    def sigmoid(self, x, derivative=False):
        '''
            Forward path:
            σ(x) = 1 / 1+exp(-z)

            Backward path:
            ∇σ(x) = exp(-z) / (1+exp(-z))^2
        '''
        # ---------------------------------------------------------------------
        if derivative:
            return np.exp(-x) / (1 + np.exp(-x)) ** 2
        else:
            return 1 / (1 + np.exp(-x))
        # ---------------------------------------------------------------------

    def softmax(self, x):
        '''
            softmax(x) = exp(x) / ∑exp(x)
        '''
        # Numerically stable with large exponentials
        # ---------------------------------------------------------------------
        return np.exp(x) / np.sum(np.exp(x), axis=0)
        # ---------------------------------------------------------------------


    def leaky_relu(self, x, alpha=0.01, derivative=False):
        '''
            Forward path:
            leaky_relu(x) = x if x >= 0 else αx

            Backward path:
            ∇leaky_relu(x) = 1 if x >= 0 else α
        '''
        # ---------------------------------------------------------------------
        if derivative:
            return np.where(x >= 0, 1, alpha)
        else:
            return np.maximum(alpha * x, x)
        # ---------------------------------------------------------------------

    def elu(self, x, alpha=1.0, derivative=False):
        '''
            Forward path:
            elu(x) = x if x > 0 else α(exp(x) - 1)

            Backward path:
            ∇elu(x) = 1 if x > 0 else α * exp(x)
        '''
        # ---------------------------------------------------------------------
        if derivative:
            return np.where(x > 0, 1, alpha * np.exp(x))
        else:
            return np.where(x > 0, x, alpha * (np.exp(x) - 1))
        # ---------------------------------------------------------------------


    def selu(self, x, lambda_=1.0507, alpha=1.67326, derivative=False):
        '''
            Forward path:
            selu(x) = λ * (x if x > 0 else α * (exp(x) - 1))

            Backward path:
            ∇selu(x) = λ * (1 if x > 0 else α * exp(x))
        '''
        # ---------------------------------------------------------------------
        if derivative:
            return lambda_ * np.where(x > 0, 1, alpha * np.exp(x))
        else:
            return lambda_ * np.where(x > 0, x, alpha * (np.exp(x) - 1))
        # ---------------------------------------------------------------------


    def initialize(self):
        params = {}
        for i in range(1, self.num_layers + 1):
            input_layer = self.sizes[i - 1]
            output_layer = self.sizes[i]
            params[f"W{i}"] = np.random.randn(output_layer, input_layer) * np.sqrt(1. / input_layer)
            params[f"b{i}"] = np.zeros((output_layer, 1))
        return params

    def feed_forward(self, x):
        self.cache["A0"] = x.T
        # ---------------------------------------------------------------------
        # Perform feedforward pass through each hidden layer, applying weights, biases, and activation function
        for i in range(1, self.num_layers + 1):
            self.cache[f"Z{i}"] = self.params[f"W{i}"] @ self.cache[f"A{i - 1}"] + self.params[f"b{i}"]
            self.cache[f"A{i}"] = self.activation(self.cache[f"Z{i}"])
        # ---------------------------------------------------------------------

        return self.cache[f"A{self.num_layers}"]

    def back_propagate(self, y, output):
        current_batch_size = y.shape[0]
        grads = {}
        # ---------------------------------------------------------------------
        # Backpropagate gradients through Output layer and each hidden layers

        for i in range(self.num_layers, 0, -1):
            if i == self.num_layers:
                grads[f"dZ{i}"] = output - y.T
            else:
                grads[f"dZ{i}"] = self.params[f"W{i + 1}"].T @ grads[f"dZ{i + 1}"] * self.activation(self.cache[f"Z{i}"], derivative=True)

            grads[f"dW{i}"] = grads[f"dZ{i}"] @ self.cache[f"A{i - 1}"].T / current_batch_size
            grads[f"db{i}"] = np.sum(grads[f"dZ{i}"], axis=1, keepdims=True) / current_batch_size

        # ---------------------------------------------------------------------

        self.grads = grads
        return self.grads


    def cross_entropy_loss(self, y, output):
        '''
            L(y, ŷ) = −∑ylog(ŷ).
        '''
        # ---------------------------------------------------------------------
        # Compute cross-entropy loss as the negative average log-likelihood of the correct labels
        loss = 0.0
        soft_output = self.softmax(output)
        for i in range(y.shape[0]):
            for j in range(y.shape[1]):
                if np.abs(y[i, j] - 1) < 0.0001:
                    loss += -np.log(soft_output[j, i] + 1e-6)
                    break
        return loss / y.shape[0]
        # ---------------------------------------------------------------------

    def initialize_momemtum_optimizer(self):
        momemtum_opt = {}
        for i in range(1, self.num_layers + 1):
            # ---------------------------------------------------------------------
            # Initialize zero matrices for momentum updates of weights and biases in each layer
            momemtum_opt[f"VW{i}"] = np.zeros_like(self.params[f"W{i}"])
            momemtum_opt[f"Vb{i}"] = np.zeros_like(self.params[f"b{i}"])
            # ---------------------------------------------------------------------
        return momemtum_opt

    def initialize_adam_optimizer(self):
        adam_opt = {}
        for i in range(1, self.num_layers + 1):
            # ---------------------------------------------------------------------
            # Initialize zero matrices for first and second moment estimates of weights and biases in each layer
            adam_opt[f"VW{i}"] = np.zeros_like(self.params[f"W{i}"])
            adam_opt[f"SW{i}"] = np.zeros_like(self.params[f"W{i}"])
            adam_opt[f"Vb{i}"] = np.zeros_like(self.params[f"b{i}"])
            adam_opt[f"Sb{i}"] = np.zeros_like(self.params[f"b{i}"])
            # ---------------------------------------------------------------------
        return adam_opt

    def optimize(self, l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8, t=1):

        if self.optimizer == "sgd":
            for key in self.params:
                # ---------------------------------------------------------------------
                # Update rule for SGD
                self.params[key] -= l_rate * self.grads[f"d{key}"]
                # ---------------------------------------------------------------------
        elif self.optimizer == "momentum":
            for key in self.params:
                # ---------------------------------------------------------------------
                # Update rule for Momentum
                self.momemtum_opt[f"V{key}"] = beta * self.momemtum_opt[f"V{key}"] + (1 - beta) * self.grads[f"d{key}"]
                self.params[key] -= l_rate * self.momemtum_opt[f"V{key}"]
                # ---------------------------------------------------------------------
        elif self.optimizer == "adam":
            for key in self.params:
                # ---------------------------------------------------------------------
                # Update rule for Adam
                self.adam_opt[f"V{key}"] = beta1 * self.adam_opt[f"V{key}"] + (1 - beta1) * self.grads[f"d{key}"]
                self.adam_opt[f"S{key}"] = beta2 * self.adam_opt[f"S{key}"] + (1 - beta2) * self.grads[f"d{key}"] ** 2
                V_corrected = self.adam_opt[f"V{key}"] / (1 - beta1 ** t)
                S_corrected = self.adam_opt[f"S{key}"] / (1 - beta2 ** t)
                self.params[key] -= l_rate * V_corrected / (np.sqrt(S_corrected) + epsilon)
                # ---------------------------------------------------------------------
        else:
            raise ValueError("This optimizer is currently not supported!")

    # Accuracy, loss, and training methods remain the same as defined in your original code


    def accuracy(self, y, output):
        # ---------------------------------------------------------------------
        # Calculate accuracy by comparing the pred and truth matrices

        pred = np.argmax(output, axis=0)
        truth = np.argmax(y.T, axis=0)
        acc = np.mean(pred == truth)

        return acc

        # ---------------------------------------------------------------------

    def train(self, x_train, y_train, x_val, y_val, epochs=10,
              batch_size=64, optimizer='momentum', l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8, t=1):
        # Hyperparameters
        self.epochs = epochs
        self.batch_size = batch_size
        num_batches = -(-x_train.shape[0] // self.batch_size)

        # Initialize optimizer
        self.optimizer = optimizer
        if self.optimizer == 'momentum':
          self.momemtum_opt = self.initialize_momemtum_optimizer()
        elif self.optimizer == 'adam':
          self.adam_opt = self.initialize_adam_optimizer()

        start_time = time.time()

        # Train
        for i in range(self.epochs):
            # Shuffle
            permutation = np.random.permutation(x_train.shape[0])
            x_train_shuffled = x_train[permutation]
            y_train_shuffled = y_train[permutation]

            for j in range(num_batches):
                # Batch
                begin = j * self.batch_size
                end = min(begin + self.batch_size, x_train.shape[0]-1)
                x = x_train_shuffled[begin:end]
                y = y_train_shuffled[begin:end]

                # Forward
                output = self.feed_forward(x)
                # Backprop
                grad = self.back_propagate(y, output)
                # Optimize
                self.optimize(l_rate=l_rate, beta=beta, beta1=beta1, beta2=beta2, epsilon=epsilon, t=t)

            # Evaluate performance
            # Training data
            output = self.feed_forward(x_train)
            train_acc = self.accuracy(y_train, output)
            train_loss = self.cross_entropy_loss(y_train, output)
            # Test data
            output = self.feed_forward(x_val)
            val_acc = self.accuracy(y_val, output)
            val_loss = self.cross_entropy_loss(y_val, output)
            print(f'Epoch {i+1}: {time.time()-start_time:.2f}s, train acc={train_acc:.2f}, train loss={train_loss:.2f}, '
                      f'validation acc={val_acc:.2f}, validation loss={val_loss:.2f}')

    def evaluate(self, x_test, y_test):
        # Test data
        output = self.feed_forward(x_test)
        test_acc = self.accuracy(y_test, output)
        test_loss = self.cross_entropy_loss(y_test, output)
        print(f'\nTest acc={test_acc:.2f}, Test loss={test_loss:.2f}')
        return test_acc, test_loss

# %% [markdown]
# Please run experiments with different combinations of optimizers (SGD, Momentum, and Adam) and activation functions (ReLU, Sigmoid, Tanh, Leaky ReLU, SELU, and ELU) over 20 epochs each. Consider networks with three layers (without input layer) whose number of neurons is 128, 64 and 10 respectively. Also consider two learning rates 0.01 and 0.001.
#
#
# After testing all combinations, report which combination of optimizer, activation function, and learning rate performs best.

# %%
# Run your experiments here ...

best_acc = 0
best_opt = ''
best_act = ''
best_lr = 0

for opt in ['adam', 'momentum', 'sgd']:
  for act in ['relu', 'sigmoid', 'tanh', 'leaky_relu', 'selu', 'elu'] :
    for lr in [0.01, 0.001]:
      print(f'Optimizer: {opt}, Activation: {act}, Learning Rate: {lr}')
      mlp = MLP(sizes=[784, 128, 64, 10], activation=act)
      mlp.train(x_train, y_train, x_test, y_test, epochs=20, batch_size=64, optimizer=opt, l_rate=lr, beta=.9)
      cur_acc , cur_loss = mlp.evaluate(x_test, y_test)
      if cur_acc > best_acc:
        best_acc = cur_acc
        best_opt = opt
        best_act = act
        best_lr = lr

print(f'Best accuracy: {best_acc}, Best optimizer: {best_opt}, Best activation: {best_act}, Best learning rate: {best_lr}')
# Out:
# Optimizer: adam, Activation: relu, Learning Rate: 0.01
# Epoch 1: 8.42s, train acc=0.96, train loss=1.56, validation acc=0.95, validation loss=1.57
# Epoch 2: 14.41s, train acc=0.97, train loss=1.53, validation acc=0.95, validation loss=1.55
# Epoch 3: 22.28s, train acc=0.97, train loss=1.52, validation acc=0.95, validation loss=1.53
# Epoch 4: 27.80s, train acc=0.97, train loss=1.51, validation acc=0.95, validation loss=1.53
# Epoch 5: 34.75s, train acc=0.97, train loss=1.52, validation acc=0.95, validation loss=1.54
# Epoch 6: 41.31s, train acc=0.98, train loss=1.49, validation acc=0.95, validation loss=1.51
# Epoch 7: 46.82s, train acc=0.98, train loss=1.51, validation acc=0.96, validation loss=1.52
# Epoch 8: 59.74s, train acc=0.98, train loss=1.50, validation acc=0.96, validation loss=1.52
# Epoch 9: 72.02s, train acc=0.98, train loss=1.51, validation acc=0.96, validation loss=1.53
# Epoch 10: 86.00s, train acc=0.98, train loss=1.48, validation acc=0.96, validation loss=1.51
# Epoch 11: 98.71s, train acc=0.98, train loss=1.48, validation acc=0.96, validation loss=1.51
# Epoch 12: 111.26s, train acc=0.98, train loss=1.50, validation acc=0.96, validation loss=1.52
# Epoch 13: 122.74s, train acc=0.99, train loss=1.49, validation acc=0.96, validation loss=1.52
# Epoch 14: 133.86s, train acc=0.98, train loss=1.50, validation acc=0.96, validation loss=1.52
# Epoch 15: 146.92s, train acc=0.99, train loss=1.49, validation acc=0.96, validation loss=1.51
# Epoch 16: 162.79s, train acc=0.99, train loss=1.48, validation acc=0.96, validation loss=1.50
# Epoch 17: 176.62s, train acc=0.99, train loss=1.48, validation acc=0.96, validation loss=1.51
# Epoch 18: 191.46s, train acc=0.99, train loss=1.49, validation acc=0.96, validation loss=1.51
# Epoch 19: 204.72s, train acc=0.99, train loss=1.49, validation acc=0.96, validation loss=1.52
# Epoch 20: 218.28s, train acc=0.99, train loss=1.49, validation acc=0.96, validation loss=1.52
#
# Test acc=0.96, Test loss=1.52
# Optimizer: adam, Activation: relu, Learning Rate: 0.001
# Epoch 1: 6.20s, train acc=0.97, train loss=1.53, validation acc=0.96, validation loss=1.54
# Epoch 2: 14.75s, train acc=0.98, train loss=1.52, validation acc=0.97, validation loss=1.53
# Epoch 3: 20.94s, train acc=0.98, train loss=1.51, validation acc=0.97, validation loss=1.53
# Epoch 4: 29.91s, train acc=0.99, train loss=1.50, validation acc=0.97, validation loss=1.52
# Epoch 5: 35.81s, train acc=0.99, train loss=1.49, validation acc=0.97, validation loss=1.51
# Epoch 6: 44.80s, train acc=0.99, train loss=1.48, validation acc=0.97, validation loss=1.50
# Epoch 7: 50.72s, train acc=0.99, train loss=1.49, validation acc=0.98, validation loss=1.51
# Epoch 8: 59.79s, train acc=0.99, train loss=1.48, validation acc=0.98, validation loss=1.50
# Epoch 9: 66.28s, train acc=1.00, train loss=1.48, validation acc=0.98, validation loss=1.51
# Epoch 10: 75.16s, train acc=1.00, train loss=1.48, validation acc=0.98, validation loss=1.50
# Epoch 11: 82.05s, train acc=1.00, train loss=1.48, validation acc=0.98, validation loss=1.50
# Epoch 12: 90.09s, train acc=1.00, train loss=1.47, validation acc=0.98, validation loss=1.50
# Epoch 13: 97.28s, train acc=1.00, train loss=1.49, validation acc=0.98, validation loss=1.52
# Epoch 14: 104.93s, train acc=1.00, train loss=1.48, validation acc=0.98, validation loss=1.50
# Epoch 15: 112.40s, train acc=1.00, train loss=1.47, validation acc=0.98, validation loss=1.50
# Epoch 16: 120.16s, train acc=1.00, train loss=1.47, validation acc=0.98, validation loss=1.50
# Epoch 17: 127.99s, train acc=1.00, train loss=1.47, validation acc=0.98, validation loss=1.50
# Epoch 18: 135.03s, train acc=1.00, train loss=1.47, validation acc=0.98, validation loss=1.50
# Epoch 19: 142.74s, train acc=1.00, train loss=1.47, validation acc=0.98, validation loss=1.50
# Epoch 20: 149.38s, train acc=1.00, train loss=1.48, validation acc=0.98, validation loss=1.50
#
# Test acc=0.98, Test loss=1.50
# Optimizer: adam, Activation: sigmoid, Learning Rate: 0.01
# Epoch 1: 8.75s, train acc=0.86, train loss=1.84, validation acc=0.85, validation loss=1.84
# Epoch 2: 15.45s, train acc=0.95, train loss=1.61, validation acc=0.93, validation loss=1.62
# Epoch 3: 24.70s, train acc=0.96, train loss=1.56, validation acc=0.94, validation loss=1.57
# Epoch 4: 31.23s, train acc=0.97, train loss=1.53, validation acc=0.95, validation loss=1.55
# Epoch 5: 40.51s, train acc=0.97, train loss=1.52, validation acc=0.95, validation loss=1.54
# Epoch 6: 47.02s, train acc=0.98, train loss=1.51, validation acc=0.95, validation loss=1.53
# Epoch 7: 56.19s, train acc=0.98, train loss=1.50, validation acc=0.96, validation loss=1.53
# Epoch 8: 62.76s, train acc=0.98, train loss=1.50, validation acc=0.96, validation loss=1.52
# Epoch 9: 72.02s, train acc=0.99, train loss=1.49, validation acc=0.96, validation loss=1.52
# Epoch 10: 78.76s, train acc=0.99, train loss=1.49, validation acc=0.96, validation loss=1.51
# Epoch 11: 87.37s, train acc=0.99, train loss=1.48, validation acc=0.96, validation loss=1.51
# Epoch 12: 94.79s, train acc=0.99, train loss=1.48, validation acc=0.96, validation loss=1.51
# Epoch 13: 104.71s, train acc=0.99, train loss=1.48, validation acc=0.96, validation loss=1.51
# Epoch 14: 113.09s, train acc=0.99, train loss=1.47, validation acc=0.97, validation loss=1.50
# Epoch 15: 119.49s, train acc=0.99, train loss=1.47, validation acc=0.96, validation loss=1.50
# Epoch 16: 128.38s, train acc=0.99, train loss=1.47, validation acc=0.96, validation loss=1.50
# Epoch 17: 134.79s, train acc=1.00, train loss=1.47, validation acc=0.97, validation loss=1.50
# Epoch 18: 143.54s, train acc=1.00, train loss=1.47, validation acc=0.97, validation loss=1.50
# Epoch 19: 150.04s, train acc=1.00, train loss=1.47, validation acc=0.97, validation loss=1.50
# Epoch 20: 159.20s, train acc=1.00, train loss=1.47, validation acc=0.96, validation loss=1.50
#
# Test acc=0.96, Test loss=1.50
# Optimizer: adam, Activation: sigmoid, Learning Rate: 0.001
# Epoch 1: 6.04s, train acc=0.89, train loss=1.80, validation acc=0.89, validation loss=1.80
# Epoch 2: 14.71s, train acc=0.92, train loss=1.66, validation acc=0.91, validation loss=1.67
# Epoch 3: 21.07s, train acc=0.93, train loss=1.61, validation acc=0.92, validation loss=1.62
# Epoch 4: 30.02s, train acc=0.94, train loss=1.58, validation acc=0.92, validation loss=1.59
# Epoch 5: 36.50s, train acc=0.94, train loss=1.56, validation acc=0.93, validation loss=1.57
# Epoch 6: 45.68s, train acc=0.95, train loss=1.55, validation acc=0.94, validation loss=1.56
# Epoch 7: 52.80s, train acc=0.96, train loss=1.54, validation acc=0.94, validation loss=1.55
# Epoch 8: 61.15s, train acc=0.96, train loss=1.53, validation acc=0.95, validation loss=1.55
# Epoch 9: 68.86s, train acc=0.96, train loss=1.53, validation acc=0.95, validation loss=1.54
# Epoch 10: 76.25s, train acc=0.97, train loss=1.52, validation acc=0.95, validation loss=1.54
# Epoch 11: 83.97s, train acc=0.97, train loss=1.52, validation acc=0.95, validation loss=1.53
# Epoch 12: 91.36s, train acc=0.97, train loss=1.51, validation acc=0.96, validation loss=1.53
# Epoch 13: 99.38s, train acc=0.97, train loss=1.51, validation acc=0.96, validation loss=1.52
# Epoch 14: 106.11s, train acc=0.98, train loss=1.51, validation acc=0.96, validation loss=1.52
# Epoch 15: 114.46s, train acc=0.98, train loss=1.50, validation acc=0.96, validation loss=1.52
# Epoch 16: 121.09s, train acc=0.98, train loss=1.50, validation acc=0.96, validation loss=1.52
# Epoch 17: 130.33s, train acc=0.98, train loss=1.50, validation acc=0.96, validation loss=1.52
# Epoch 18: 136.71s, train acc=0.98, train loss=1.50, validation acc=0.97, validation loss=1.51
# Epoch 19: 145.84s, train acc=0.98, train loss=1.49, validation acc=0.97, validation loss=1.51
# Epoch 20: 152.55s, train acc=0.98, train loss=1.49, validation acc=0.97, validation loss=1.51
#
# Test acc=0.97, Test loss=1.51
# Optimizer: adam, Activation: tanh, Learning Rate: 0.01
# Epoch 1: 10.99s, train acc=0.95, train loss=1.56, validation acc=0.93, validation loss=1.57
# Epoch 2: 21.77s, train acc=0.96, train loss=1.54, validation acc=0.94, validation loss=1.55
# Epoch 3: 30.30s, train acc=0.97, train loss=1.53, validation acc=0.95, validation loss=1.54
# Epoch 4: 41.62s, train acc=0.97, train loss=1.52, validation acc=0.96, validation loss=1.53
# Epoch 5: 52.97s, train acc=0.97, train loss=1.51, validation acc=0.95, validation loss=1.52
# Epoch 6: 62.38s, train acc=0.97, train loss=1.51, validation acc=0.95, validation loss=1.53
# Epoch 7: 72.54s, train acc=0.97, train loss=1.50, validation acc=0.95, validation loss=1.52
# Epoch 8: 84.08s, train acc=0.98, train loss=1.50, validation acc=0.96, validation loss=1.52
# Epoch 9: 97.19s, train acc=0.98, train loss=1.50, validation acc=0.96, validation loss=1.52
# Epoch 10: 105.77s, train acc=0.98, train loss=1.49, validation acc=0.95, validation loss=1.51
# Epoch 11: 117.03s, train acc=0.98, train loss=1.49, validation acc=0.96, validation loss=1.51
# Epoch 12: 127.88s, train acc=0.98, train loss=1.49, validation acc=0.96, validation loss=1.52
# Epoch 13: 136.39s, train acc=0.98, train loss=1.50, validation acc=0.96, validation loss=1.52
# Epoch 14: 146.95s, train acc=0.98, train loss=1.50, validation acc=0.96, validation loss=1.52
# Epoch 15: 158.10s, train acc=0.99, train loss=1.50, validation acc=0.96, validation loss=1.52
# Epoch 16: 166.99s, train acc=0.98, train loss=1.50, validation acc=0.96, validation loss=1.52
# Epoch 17: 177.02s, train acc=0.99, train loss=1.49, validation acc=0.96, validation loss=1.51
# Epoch 18: 187.78s, train acc=0.98, train loss=1.50, validation acc=0.96, validation loss=1.52
# Epoch 19: 198.11s, train acc=0.98, train loss=1.49, validation acc=0.96, validation loss=1.51
# Epoch 20: 207.05s, train acc=0.99, train loss=1.49, validation acc=0.96, validation loss=1.52
#
# Test acc=0.96, Test loss=1.52
# Optimizer: adam, Activation: tanh, Learning Rate: 0.001
# Epoch 1: 10.99s, train acc=0.93, train loss=1.62, validation acc=0.92, validation loss=1.63
# Epoch 2: 21.39s, train acc=0.95, train loss=1.58, validation acc=0.93, validation loss=1.59
# Epoch 3: 29.97s, train acc=0.95, train loss=1.56, validation acc=0.94, validation loss=1.57
# Epoch 4: 40.54s, train acc=0.96, train loss=1.55, validation acc=0.95, validation loss=1.56
# Epoch 5: 50.94s, train acc=0.96, train loss=1.54, validation acc=0.95, validation loss=1.55
# Epoch 6: 59.05s, train acc=0.97, train loss=1.54, validation acc=0.95, validation loss=1.55
# Epoch 7: 69.86s, train acc=0.97, train loss=1.52, validation acc=0.96, validation loss=1.54
# Epoch 8: 79.95s, train acc=0.97, train loss=1.52, validation acc=0.96, validation loss=1.53
# Epoch 9: 88.26s, train acc=0.98, train loss=1.51, validation acc=0.96, validation loss=1.53
# Epoch 10: 99.13s, train acc=0.98, train loss=1.51, validation acc=0.96, validation loss=1.52
# Epoch 11: 108.80s, train acc=0.98, train loss=1.51, validation acc=0.96, validation loss=1.52
# Epoch 12: 116.91s, train acc=0.98, train loss=1.50, validation acc=0.96, validation loss=1.52
# Epoch 13: 127.95s, train acc=0.98, train loss=1.50, validation acc=0.97, validation loss=1.51
# Epoch 14: 137.71s, train acc=0.98, train loss=1.49, validation acc=0.97, validation loss=1.51
# Epoch 15: 146.25s, train acc=0.99, train loss=1.50, validation acc=0.97, validation loss=1.51
# Epoch 16: 157.20s, train acc=0.99, train loss=1.49, validation acc=0.97, validation loss=1.51
# Epoch 17: 166.74s, train acc=0.99, train loss=1.49, validation acc=0.97, validation loss=1.51
# Epoch 18: 175.06s, train acc=0.99, train loss=1.49, validation acc=0.97, validation loss=1.51
# Epoch 19: 187.70s, train acc=0.99, train loss=1.49, validation acc=0.97, validation loss=1.50
# Epoch 20: 198.59s, train acc=0.99, train loss=1.48, validation acc=0.97, validation loss=1.50
#
# Test acc=0.97, Test loss=1.50
# Optimizer: adam, Activation: leaky_relu, Learning Rate: 0.01
# Epoch 1: 5.66s, train acc=0.96, train loss=1.56, validation acc=0.95, validation loss=1.57
# Epoch 2: 13.87s, train acc=0.97, train loss=1.53, validation acc=0.96, validation loss=1.54
# Epoch 3: 19.47s, train acc=0.97, train loss=1.51, validation acc=0.96, validation loss=1.52
# Epoch 4: 28.03s, train acc=0.98, train loss=1.51, validation acc=0.96, validation loss=1.53
# Epoch 5: 33.94s, train acc=0.98, train loss=1.51, validation acc=0.96, validation loss=1.52
# Epoch 6: 42.07s, train acc=0.98, train loss=1.49, validation acc=0.96, validation loss=1.51
# Epoch 7: 47.78s, train acc=0.98, train loss=1.48, validation acc=0.96, validation loss=1.50
# Epoch 8: 54.92s, train acc=0.99, train loss=1.49, validation acc=0.97, validation loss=1.51
# Epoch 9: 61.52s, train acc=0.99, train loss=1.49, validation acc=0.97, validation loss=1.51
# Epoch 10: 67.33s, train acc=0.99, train loss=1.49, validation acc=0.96, validation loss=1.51
# Epoch 11: 75.16s, train acc=0.99, train loss=1.48, validation acc=0.96, validation loss=1.50
# Epoch 12: 80.63s, train acc=0.99, train loss=1.47, validation acc=0.97, validation loss=1.49
# Epoch 13: 89.25s, train acc=0.99, train loss=1.48, validation acc=0.97, validation loss=1.51
# Epoch 14: 94.67s, train acc=0.99, train loss=1.49, validation acc=0.97, validation loss=1.52
# Epoch 15: 103.00s, train acc=0.99, train loss=1.47, validation acc=0.97, validation loss=1.49
# Epoch 16: 108.43s, train acc=0.99, train loss=1.49, validation acc=0.97, validation loss=1.51
# Epoch 17: 116.03s, train acc=0.99, train loss=1.48, validation acc=0.97, validation loss=1.51
# Epoch 18: 121.52s, train acc=0.99, train loss=1.48, validation acc=0.97, validation loss=1.51
# Epoch 19: 127.93s, train acc=0.99, train loss=1.49, validation acc=0.97, validation loss=1.51
# Epoch 20: 135.09s, train acc=0.99, train loss=1.48, validation acc=0.97, validation loss=1.50
#
# Test acc=0.97, Test loss=1.50
# Optimizer: adam, Activation: leaky_relu, Learning Rate: 0.001
# Epoch 1: 5.34s, train acc=0.97, train loss=1.55, validation acc=0.96, validation loss=1.56
# Epoch 2: 13.76s, train acc=0.98, train loss=1.52, validation acc=0.97, validation loss=1.54
# Epoch 3: 19.52s, train acc=0.98, train loss=1.51, validation acc=0.97, validation loss=1.53
# Epoch 4: 28.04s, train acc=0.99, train loss=1.50, validation acc=0.97, validation loss=1.52
# Epoch 5: 33.58s, train acc=0.99, train loss=1.50, validation acc=0.97, validation loss=1.52
# Epoch 6: 41.54s, train acc=0.99, train loss=1.50, validation acc=0.97, validation loss=1.52
# Epoch 7: 47.09s, train acc=0.99, train loss=1.49, validation acc=0.97, validation loss=1.51
# Epoch 8: 55.08s, train acc=0.99, train loss=1.48, validation acc=0.98, validation loss=1.50
# Epoch 9: 60.74s, train acc=1.00, train loss=1.48, validation acc=0.98, validation loss=1.50
# Epoch 10: 68.29s, train acc=1.00, train loss=1.48, validation acc=0.98, validation loss=1.51
# Epoch 11: 74.19s, train acc=1.00, train loss=1.48, validation acc=0.98, validation loss=1.50
# Epoch 12: 80.45s, train acc=1.00, train loss=1.48, validation acc=0.98, validation loss=1.50
# Epoch 13: 87.47s, train acc=1.00, train loss=1.48, validation acc=0.98, validation loss=1.51
# Epoch 14: 93.34s, train acc=1.00, train loss=1.47, validation acc=0.98, validation loss=1.50
# Epoch 15: 101.17s, train acc=1.00, train loss=1.48, validation acc=0.98, validation loss=1.50
# Epoch 16: 106.71s, train acc=1.00, train loss=1.47, validation acc=0.98, validation loss=1.50
# Epoch 17: 114.87s, train acc=1.00, train loss=1.47, validation acc=0.98, validation loss=1.50
# Epoch 18: 120.61s, train acc=1.00, train loss=1.47, validation acc=0.98, validation loss=1.50
# Epoch 19: 128.84s, train acc=1.00, train loss=1.47, validation acc=0.98, validation loss=1.50
# Epoch 20: 134.34s, train acc=1.00, train loss=1.47, validation acc=0.98, validation loss=1.50
#
# Test acc=0.98, Test loss=1.50
# Optimizer: adam, Activation: selu, Learning Rate: 0.01
# Epoch 1: 9.26s, train acc=0.89, train loss=1.70, validation acc=0.87, validation loss=1.71
# Epoch 2: 15.45s, train acc=0.93, train loss=1.61, validation acc=0.91, validation loss=1.62
# Epoch 3: 26.11s, train acc=0.94, train loss=1.57, validation acc=0.93, validation loss=1.59
# Epoch 4: 32.45s, train acc=0.95, train loss=1.58, validation acc=0.93, validation loss=1.59
# Epoch 5: 41.51s, train acc=0.96, train loss=1.57, validation acc=0.94, validation loss=1.58
# Epoch 6: 47.98s, train acc=0.96, train loss=1.55, validation acc=0.95, validation loss=1.56
# Epoch 7: 57.52s, train acc=0.97, train loss=1.53, validation acc=0.95, validation loss=1.54
# Epoch 8: 64.11s, train acc=0.97, train loss=1.56, validation acc=0.95, validation loss=1.58
# Epoch 9: 73.37s, train acc=0.97, train loss=1.52, validation acc=0.96, validation loss=1.53
# Epoch 10: 79.68s, train acc=0.97, train loss=1.55, validation acc=0.96, validation loss=1.57
# Epoch 11: 88.92s, train acc=0.98, train loss=1.53, validation acc=0.96, validation loss=1.55
# Epoch 12: 95.34s, train acc=0.98, train loss=1.49, validation acc=0.96, validation loss=1.51
# Epoch 13: 103.96s, train acc=0.98, train loss=1.52, validation acc=0.96, validation loss=1.54
# Epoch 14: 110.20s, train acc=0.98, train loss=1.52, validation acc=0.96, validation loss=1.54
# Epoch 15: 119.00s, train acc=0.99, train loss=1.49, validation acc=0.97, validation loss=1.51
# Epoch 16: 125.77s, train acc=0.99, train loss=1.50, validation acc=0.97, validation loss=1.52
# Epoch 17: 133.87s, train acc=0.99, train loss=1.50, validation acc=0.97, validation loss=1.52
# Epoch 18: 140.63s, train acc=0.99, train loss=1.49, validation acc=0.97, validation loss=1.52
# Epoch 19: 148.59s, train acc=0.99, train loss=1.50, validation acc=0.97, validation loss=1.53
# Epoch 20: 155.37s, train acc=0.99, train loss=1.52, validation acc=0.97, validation loss=1.54
#
# Test acc=0.97, Test loss=1.54
# Optimizer: adam, Activation: selu, Learning Rate: 0.001
# Epoch 1: 7.37s, train acc=0.91, train loss=1.70, validation acc=0.90, validation loss=1.71
# Epoch 2: 14.14s, train acc=0.93, train loss=1.65, validation acc=0.92, validation loss=1.66
# Epoch 3: 21.37s, train acc=0.94, train loss=1.62, validation acc=0.93, validation loss=1.63
# Epoch 4: 28.34s, train acc=0.95, train loss=1.61, validation acc=0.93, validation loss=1.63
# Epoch 5: 35.55s, train acc=0.95, train loss=1.59, validation acc=0.94, validation loss=1.61
# Epoch 6: 43.14s, train acc=0.95, train loss=1.58, validation acc=0.94, validation loss=1.60
# Epoch 7: 50.01s, train acc=0.96, train loss=1.57, validation acc=0.94, validation loss=1.58
# Epoch 8: 57.84s, train acc=0.96, train loss=1.57, validation acc=0.95, validation loss=1.59
# Epoch 9: 64.78s, train acc=0.96, train loss=1.57, validation acc=0.95, validation loss=1.58
# Epoch 10: 72.80s, train acc=0.97, train loss=1.56, validation acc=0.95, validation loss=1.58
# Epoch 11: 78.98s, train acc=0.97, train loss=1.55, validation acc=0.95, validation loss=1.57
# Epoch 12: 87.74s, train acc=0.97, train loss=1.55, validation acc=0.95, validation loss=1.57
# Epoch 13: 94.54s, train acc=0.97, train loss=1.55, validation acc=0.95, validation loss=1.56
# Epoch 14: 103.47s, train acc=0.97, train loss=1.54, validation acc=0.95, validation loss=1.56
# Epoch 15: 109.64s, train acc=0.97, train loss=1.54, validation acc=0.95, validation loss=1.56
# Epoch 16: 118.51s, train acc=0.97, train loss=1.54, validation acc=0.96, validation loss=1.56
# Epoch 17: 124.82s, train acc=0.97, train loss=1.54, validation acc=0.96, validation loss=1.56
# Epoch 18: 133.84s, train acc=0.97, train loss=1.54, validation acc=0.96, validation loss=1.56
# Epoch 19: 140.03s, train acc=0.97, train loss=1.54, validation acc=0.96, validation loss=1.55
# Epoch 20: 149.29s, train acc=0.97, train loss=1.54, validation acc=0.96, validation loss=1.56
#
# Test acc=0.96, Test loss=1.56
# Optimizer: adam, Activation: elu, Learning Rate: 0.01
# Epoch 1: 6.20s, train acc=0.93, train loss=1.62, validation acc=0.92, validation loss=1.64
# Epoch 2: 14.98s, train acc=0.95, train loss=1.60, validation acc=0.94, validation loss=1.61
# Epoch 3: 24.73s, train acc=0.96, train loss=1.57, validation acc=0.94, validation loss=1.58
# Epoch 4: 31.91s, train acc=0.97, train loss=1.54, validation acc=0.95, validation loss=1.56
# Epoch 5: 38.76s, train acc=0.97, train loss=1.54, validation acc=0.96, validation loss=1.56
# Epoch 6: 46.46s, train acc=0.97, train loss=1.54, validation acc=0.96, validation loss=1.56
# Epoch 7: 53.50s, train acc=0.98, train loss=1.51, validation acc=0.96, validation loss=1.52
# Epoch 8: 61.03s, train acc=0.98, train loss=1.52, validation acc=0.96, validation loss=1.54
# Epoch 9: 68.11s, train acc=0.98, train loss=1.52, validation acc=0.96, validation loss=1.54
# Epoch 10: 75.88s, train acc=0.98, train loss=1.50, validation acc=0.97, validation loss=1.52
# Epoch 11: 83.19s, train acc=0.99, train loss=1.50, validation acc=0.97, validation loss=1.52
# Epoch 12: 90.36s, train acc=0.99, train loss=1.50, validation acc=0.97, validation loss=1.52
# Epoch 13: 97.74s, train acc=0.99, train loss=1.49, validation acc=0.97, validation loss=1.51
# Epoch 14: 105.10s, train acc=0.99, train loss=1.47, validation acc=0.97, validation loss=1.50
# Epoch 15: 112.22s, train acc=0.99, train loss=1.50, validation acc=0.97, validation loss=1.52
# Epoch 16: 119.41s, train acc=0.99, train loss=1.50, validation acc=0.97, validation loss=1.52
# Epoch 17: 126.69s, train acc=0.99, train loss=1.49, validation acc=0.97, validation loss=1.52
# Epoch 18: 134.17s, train acc=0.99, train loss=1.48, validation acc=0.97, validation loss=1.51
# Epoch 19: 141.80s, train acc=0.99, train loss=1.48, validation acc=0.97, validation loss=1.51
# Epoch 20: 149.11s, train acc=0.99, train loss=1.48, validation acc=0.97, validation loss=1.51
#
# Test acc=0.97, Test loss=1.51
# Optimizer: adam, Activation: elu, Learning Rate: 0.001
# Epoch 1: 7.99s, train acc=0.94, train loss=1.63, validation acc=0.93, validation loss=1.64
# Epoch 2: 14.73s, train acc=0.95, train loss=1.60, validation acc=0.95, validation loss=1.61
# Epoch 3: 22.70s, train acc=0.96, train loss=1.57, validation acc=0.95, validation loss=1.58
# Epoch 4: 29.43s, train acc=0.97, train loss=1.57, validation acc=0.96, validation loss=1.58
# Epoch 5: 37.72s, train acc=0.97, train loss=1.55, validation acc=0.96, validation loss=1.56
# Epoch 6: 44.50s, train acc=0.97, train loss=1.54, validation acc=0.96, validation loss=1.56
# Epoch 7: 53.55s, train acc=0.98, train loss=1.54, validation acc=0.96, validation loss=1.56
# Epoch 8: 60.01s, train acc=0.98, train loss=1.54, validation acc=0.97, validation loss=1.55
# Epoch 9: 68.73s, train acc=0.98, train loss=1.53, validation acc=0.97, validation loss=1.54
# Epoch 10: 74.98s, train acc=0.98, train loss=1.53, validation acc=0.97, validation loss=1.55
# Epoch 11: 84.01s, train acc=0.98, train loss=1.51, validation acc=0.97, validation loss=1.53
# Epoch 12: 90.27s, train acc=0.98, train loss=1.52, validation acc=0.97, validation loss=1.53
# Epoch 13: 99.12s, train acc=0.98, train loss=1.51, validation acc=0.97, validation loss=1.53
# Epoch 14: 105.53s, train acc=0.98, train loss=1.52, validation acc=0.97, validation loss=1.53
# Epoch 15: 114.57s, train acc=0.99, train loss=1.51, validation acc=0.97, validation loss=1.53
# Epoch 16: 120.95s, train acc=0.99, train loss=1.50, validation acc=0.97, validation loss=1.52
# Epoch 17: 129.15s, train acc=0.99, train loss=1.51, validation acc=0.97, validation loss=1.53
# Epoch 18: 136.21s, train acc=0.99, train loss=1.51, validation acc=0.97, validation loss=1.53
# Epoch 19: 143.93s, train acc=0.99, train loss=1.50, validation acc=0.97, validation loss=1.52
# Epoch 20: 151.36s, train acc=0.99, train loss=1.50, validation acc=0.98, validation loss=1.52
#
# Test acc=0.98, Test loss=1.52
# Optimizer: momentum, Activation: relu, Learning Rate: 0.01
# Epoch 1: 5.05s, train acc=0.87, train loss=1.77, validation acc=0.85, validation loss=1.78
# Epoch 2: 9.18s, train acc=0.90, train loss=1.69, validation acc=0.89, validation loss=1.70
# Epoch 3: 14.98s, train acc=0.92, train loss=1.66, validation acc=0.90, validation loss=1.67
# Epoch 4: 22.12s, train acc=0.93, train loss=1.64, validation acc=0.91, validation loss=1.65
# Epoch 5: 26.44s, train acc=0.93, train loss=1.63, validation acc=0.92, validation loss=1.64
# Epoch 6: 33.54s, train acc=0.94, train loss=1.61, validation acc=0.93, validation loss=1.62
# Epoch 7: 37.75s, train acc=0.94, train loss=1.61, validation acc=0.93, validation loss=1.62
# Epoch 8: 41.97s, train acc=0.95, train loss=1.60, validation acc=0.94, validation loss=1.61
# Epoch 9: 49.37s, train acc=0.95, train loss=1.59, validation acc=0.94, validation loss=1.60
# Epoch 10: 53.72s, train acc=0.95, train loss=1.59, validation acc=0.94, validation loss=1.60
# Epoch 11: 58.45s, train acc=0.95, train loss=1.58, validation acc=0.94, validation loss=1.59
# Epoch 12: 65.56s, train acc=0.96, train loss=1.58, validation acc=0.95, validation loss=1.59
# Epoch 13: 70.02s, train acc=0.96, train loss=1.57, validation acc=0.95, validation loss=1.58
# Epoch 14: 75.14s, train acc=0.96, train loss=1.57, validation acc=0.95, validation loss=1.58
# Epoch 15: 81.28s, train acc=0.96, train loss=1.56, validation acc=0.95, validation loss=1.58
# Epoch 16: 85.53s, train acc=0.96, train loss=1.56, validation acc=0.95, validation loss=1.57
# Epoch 17: 91.84s, train acc=0.96, train loss=1.56, validation acc=0.95, validation loss=1.57
# Epoch 18: 96.48s, train acc=0.96, train loss=1.56, validation acc=0.95, validation loss=1.57
# Epoch 19: 100.84s, train acc=0.97, train loss=1.55, validation acc=0.96, validation loss=1.56
# Epoch 20: 108.06s, train acc=0.97, train loss=1.55, validation acc=0.96, validation loss=1.56
#
# Test acc=0.96, Test loss=1.56
# Optimizer: momentum, Activation: relu, Learning Rate: 0.001
# Epoch 1: 4.35s, train acc=0.49, train loss=2.17, validation acc=0.49, validation loss=2.18
# Epoch 2: 8.67s, train acc=0.69, train loss=2.08, validation acc=0.67, validation loss=2.08
# Epoch 3: 15.99s, train acc=0.76, train loss=2.01, validation acc=0.75, validation loss=2.01
# Epoch 4: 20.34s, train acc=0.80, train loss=1.95, validation acc=0.79, validation loss=1.95
# Epoch 5: 25.41s, train acc=0.82, train loss=1.90, validation acc=0.81, validation loss=1.90
# Epoch 6: 31.42s, train acc=0.84, train loss=1.86, validation acc=0.82, validation loss=1.87
# Epoch 7: 35.56s, train acc=0.85, train loss=1.83, validation acc=0.84, validation loss=1.84
# Epoch 8: 41.14s, train acc=0.86, train loss=1.81, validation acc=0.84, validation loss=1.82
# Epoch 9: 46.75s, train acc=0.87, train loss=1.79, validation acc=0.85, validation loss=1.80
# Epoch 10: 51.12s, train acc=0.87, train loss=1.77, validation acc=0.86, validation loss=1.78
# Epoch 11: 57.49s, train acc=0.88, train loss=1.76, validation acc=0.86, validation loss=1.77
# Epoch 12: 62.00s, train acc=0.88, train loss=1.75, validation acc=0.87, validation loss=1.76
# Epoch 13: 66.44s, train acc=0.89, train loss=1.74, validation acc=0.87, validation loss=1.75
# Epoch 14: 73.72s, train acc=0.89, train loss=1.73, validation acc=0.88, validation loss=1.74
# Epoch 15: 78.12s, train acc=0.89, train loss=1.72, validation acc=0.88, validation loss=1.73
# Epoch 16: 82.48s, train acc=0.89, train loss=1.71, validation acc=0.88, validation loss=1.72
# Epoch 17: 89.61s, train acc=0.90, train loss=1.70, validation acc=0.88, validation loss=1.71
# Epoch 18: 93.99s, train acc=0.90, train loss=1.70, validation acc=0.89, validation loss=1.71
# Epoch 19: 98.98s, train acc=0.90, train loss=1.69, validation acc=0.89, validation loss=1.70
# Epoch 20: 105.38s, train acc=0.90, train loss=1.69, validation acc=0.89, validation loss=1.70
#
# Test acc=0.89, Test loss=1.70
# Optimizer: momentum, Activation: sigmoid, Learning Rate: 0.01
# Epoch 1: 5.25s, train acc=0.17, train loss=2.30, validation acc=0.17, validation loss=2.30
# Epoch 2: 13.10s, train acc=0.38, train loss=2.29, validation acc=0.38, validation loss=2.29
# Epoch 3: 18.28s, train acc=0.54, train loss=2.27, validation acc=0.53, validation loss=2.27
# Epoch 4: 25.85s, train acc=0.59, train loss=2.22, validation acc=0.58, validation loss=2.22
# Epoch 5: 31.11s, train acc=0.64, train loss=2.14, validation acc=0.63, validation loss=2.14
# Epoch 6: 36.47s, train acc=0.69, train loss=2.07, validation acc=0.68, validation loss=2.08
# Epoch 7: 44.41s, train acc=0.72, train loss=2.02, validation acc=0.71, validation loss=2.02
# Epoch 8: 49.75s, train acc=0.75, train loss=1.97, validation acc=0.74, validation loss=1.97
# Epoch 9: 57.66s, train acc=0.79, train loss=1.93, validation acc=0.79, validation loss=1.93
# Epoch 10: 62.87s, train acc=0.82, train loss=1.89, validation acc=0.81, validation loss=1.90
# Epoch 11: 69.56s, train acc=0.83, train loss=1.86, validation acc=0.83, validation loss=1.87
# Epoch 12: 75.45s, train acc=0.84, train loss=1.83, validation acc=0.84, validation loss=1.84
# Epoch 13: 80.83s, train acc=0.86, train loss=1.80, validation acc=0.85, validation loss=1.81
# Epoch 14: 88.51s, train acc=0.86, train loss=1.78, validation acc=0.86, validation loss=1.79
# Epoch 15: 93.80s, train acc=0.87, train loss=1.76, validation acc=0.86, validation loss=1.77
# Epoch 16: 103.60s, train acc=0.88, train loss=1.75, validation acc=0.87, validation loss=1.76
# Epoch 17: 108.97s, train acc=0.88, train loss=1.74, validation acc=0.87, validation loss=1.74
# Epoch 18: 116.14s, train acc=0.88, train loss=1.72, validation acc=0.88, validation loss=1.73
# Epoch 19: 121.49s, train acc=0.89, train loss=1.71, validation acc=0.88, validation loss=1.72
# Epoch 20: 126.69s, train acc=0.89, train loss=1.70, validation acc=0.88, validation loss=1.71
#
# Test acc=0.88, Test loss=1.71
# Optimizer: momentum, Activation: sigmoid, Learning Rate: 0.001
# Epoch 1: 7.91s, train acc=0.14, train loss=2.30, validation acc=0.14, validation loss=2.30
# Epoch 2: 13.32s, train acc=0.11, train loss=2.30, validation acc=0.11, validation loss=2.30
# Epoch 3: 21.38s, train acc=0.11, train loss=2.30, validation acc=0.11, validation loss=2.30
# Epoch 4: 26.63s, train acc=0.11, train loss=2.30, validation acc=0.11, validation loss=2.30
# Epoch 5: 34.06s, train acc=0.11, train loss=2.30, validation acc=0.11, validation loss=2.30
# Epoch 6: 39.30s, train acc=0.11, train loss=2.30, validation acc=0.11, validation loss=2.30
# Epoch 7: 45.67s, train acc=0.12, train loss=2.30, validation acc=0.12, validation loss=2.30
# Epoch 8: 52.56s, train acc=0.13, train loss=2.30, validation acc=0.13, validation loss=2.30
# Epoch 9: 58.00s, train acc=0.15, train loss=2.30, validation acc=0.15, validation loss=2.30
# Epoch 10: 66.32s, train acc=0.18, train loss=2.30, validation acc=0.18, validation loss=2.30
# Epoch 11: 71.87s, train acc=0.19, train loss=2.30, validation acc=0.20, validation loss=2.30
# Epoch 12: 79.89s, train acc=0.22, train loss=2.30, validation acc=0.23, validation loss=2.30
# Epoch 13: 85.33s, train acc=0.29, train loss=2.30, validation acc=0.29, validation loss=2.30
# Epoch 14: 92.16s, train acc=0.26, train loss=2.30, validation acc=0.26, validation loss=2.30
# Epoch 15: 98.06s, train acc=0.29, train loss=2.30, validation acc=0.29, validation loss=2.30
# Epoch 16: 104.15s, train acc=0.30, train loss=2.29, validation acc=0.30, validation loss=2.29
# Epoch 17: 111.86s, train acc=0.32, train loss=2.29, validation acc=0.32, validation loss=2.29
# Epoch 18: 117.21s, train acc=0.35, train loss=2.29, validation acc=0.34, validation loss=2.29
# Epoch 19: 125.45s, train acc=0.40, train loss=2.29, validation acc=0.39, validation loss=2.29
# Epoch 20: 130.85s, train acc=0.40, train loss=2.29, validation acc=0.39, validation loss=2.29
#
# Test acc=0.39, Test loss=2.29
# Optimizer: momentum, Activation: tanh, Learning Rate: 0.01
# Epoch 1: 9.99s, train acc=0.84, train loss=1.86, validation acc=0.83, validation loss=1.87
# Epoch 2: 17.06s, train acc=0.86, train loss=1.83, validation acc=0.84, validation loss=1.84
# Epoch 3: 26.88s, train acc=0.88, train loss=1.79, validation acc=0.86, validation loss=1.80
# Epoch 4: 34.59s, train acc=0.89, train loss=1.76, validation acc=0.87, validation loss=1.77
# Epoch 5: 42.68s, train acc=0.90, train loss=1.73, validation acc=0.88, validation loss=1.74
# Epoch 6: 51.92s, train acc=0.90, train loss=1.71, validation acc=0.89, validation loss=1.72
# Epoch 7: 59.23s, train acc=0.91, train loss=1.69, validation acc=0.90, validation loss=1.70
# Epoch 8: 68.98s, train acc=0.92, train loss=1.68, validation acc=0.90, validation loss=1.69
# Epoch 9: 75.97s, train acc=0.92, train loss=1.67, validation acc=0.91, validation loss=1.68
# Epoch 10: 85.83s, train acc=0.92, train loss=1.66, validation acc=0.91, validation loss=1.67
# Epoch 11: 93.78s, train acc=0.92, train loss=1.65, validation acc=0.91, validation loss=1.66
# Epoch 12: 101.56s, train acc=0.93, train loss=1.64, validation acc=0.91, validation loss=1.65
# Epoch 13: 110.52s, train acc=0.93, train loss=1.63, validation acc=0.92, validation loss=1.64
# Epoch 14: 117.59s, train acc=0.93, train loss=1.63, validation acc=0.92, validation loss=1.64
# Epoch 15: 127.37s, train acc=0.93, train loss=1.62, validation acc=0.92, validation loss=1.63
# Epoch 16: 135.39s, train acc=0.93, train loss=1.62, validation acc=0.92, validation loss=1.63
# Epoch 17: 145.65s, train acc=0.94, train loss=1.61, validation acc=0.92, validation loss=1.62
# Epoch 18: 153.43s, train acc=0.94, train loss=1.61, validation acc=0.93, validation loss=1.62
# Epoch 19: 161.36s, train acc=0.94, train loss=1.61, validation acc=0.93, validation loss=1.62
# Epoch 20: 170.30s, train acc=0.94, train loss=1.60, validation acc=0.93, validation loss=1.61
#
# Test acc=0.93, Test loss=1.61
# Optimizer: momentum, Activation: tanh, Learning Rate: 0.001
# Epoch 1: 7.42s, train acc=0.69, train loss=2.00, validation acc=0.68, validation loss=2.01
# Epoch 2: 16.96s, train acc=0.77, train loss=1.94, validation acc=0.76, validation loss=1.95
# Epoch 3: 24.82s, train acc=0.80, train loss=1.92, validation acc=0.79, validation loss=1.92
# Epoch 4: 33.44s, train acc=0.81, train loss=1.90, validation acc=0.80, validation loss=1.91
# Epoch 5: 42.02s, train acc=0.82, train loss=1.89, validation acc=0.81, validation loss=1.89
# Epoch 6: 49.07s, train acc=0.83, train loss=1.88, validation acc=0.81, validation loss=1.89
# Epoch 7: 58.58s, train acc=0.84, train loss=1.87, validation acc=0.82, validation loss=1.88
# Epoch 8: 65.55s, train acc=0.84, train loss=1.87, validation acc=0.82, validation loss=1.87
# Epoch 9: 75.43s, train acc=0.84, train loss=1.86, validation acc=0.82, validation loss=1.87
# Epoch 10: 83.35s, train acc=0.85, train loss=1.85, validation acc=0.83, validation loss=1.86
# Epoch 11: 91.27s, train acc=0.85, train loss=1.85, validation acc=0.83, validation loss=1.86
# Epoch 12: 99.98s, train acc=0.85, train loss=1.85, validation acc=0.83, validation loss=1.85
# Epoch 13: 107.03s, train acc=0.85, train loss=1.84, validation acc=0.84, validation loss=1.85
# Epoch 14: 116.67s, train acc=0.85, train loss=1.84, validation acc=0.84, validation loss=1.85
# Epoch 15: 123.77s, train acc=0.86, train loss=1.83, validation acc=0.84, validation loss=1.84
# Epoch 16: 133.48s, train acc=0.86, train loss=1.83, validation acc=0.84, validation loss=1.84
# Epoch 17: 141.18s, train acc=0.86, train loss=1.82, validation acc=0.84, validation loss=1.83
# Epoch 18: 149.45s, train acc=0.86, train loss=1.82, validation acc=0.85, validation loss=1.83
# Epoch 19: 157.62s, train acc=0.87, train loss=1.82, validation acc=0.85, validation loss=1.82
# Epoch 20: 164.72s, train acc=0.87, train loss=1.81, validation acc=0.85, validation loss=1.82
#
# Test acc=0.85, Test loss=1.82
# Optimizer: momentum, Activation: leaky_relu, Learning Rate: 0.01
# Epoch 1: 5.17s, train acc=0.87, train loss=1.76, validation acc=0.86, validation loss=1.76
# Epoch 2: 10.60s, train acc=0.90, train loss=1.69, validation acc=0.89, validation loss=1.70
# Epoch 3: 14.87s, train acc=0.92, train loss=1.66, validation acc=0.90, validation loss=1.67
# Epoch 4: 20.27s, train acc=0.93, train loss=1.64, validation acc=0.91, validation loss=1.65
# Epoch 5: 25.32s, train acc=0.93, train loss=1.63, validation acc=0.92, validation loss=1.64
# Epoch 6: 29.52s, train acc=0.94, train loss=1.62, validation acc=0.92, validation loss=1.63
# Epoch 7: 35.36s, train acc=0.94, train loss=1.61, validation acc=0.93, validation loss=1.62
# Epoch 8: 39.91s, train acc=0.94, train loss=1.60, validation acc=0.93, validation loss=1.61
# Epoch 9: 44.07s, train acc=0.95, train loss=1.60, validation acc=0.94, validation loss=1.61
# Epoch 10: 50.30s, train acc=0.95, train loss=1.59, validation acc=0.94, validation loss=1.61
# Epoch 11: 55.28s, train acc=0.95, train loss=1.59, validation acc=0.94, validation loss=1.60
# Epoch 12: 59.76s, train acc=0.96, train loss=1.59, validation acc=0.94, validation loss=1.60
# Epoch 13: 66.38s, train acc=0.96, train loss=1.58, validation acc=0.94, validation loss=1.59
# Epoch 14: 71.06s, train acc=0.96, train loss=1.58, validation acc=0.94, validation loss=1.59
# Epoch 15: 75.41s, train acc=0.96, train loss=1.57, validation acc=0.95, validation loss=1.59
# Epoch 16: 82.79s, train acc=0.96, train loss=1.57, validation acc=0.95, validation loss=1.58
# Epoch 17: 87.15s, train acc=0.96, train loss=1.57, validation acc=0.95, validation loss=1.58
# Epoch 18: 92.82s, train acc=0.96, train loss=1.57, validation acc=0.95, validation loss=1.58
# Epoch 19: 100.90s, train acc=0.96, train loss=1.56, validation acc=0.95, validation loss=1.58
# Epoch 20: 105.39s, train acc=0.97, train loss=1.56, validation acc=0.95, validation loss=1.57
#
# Test acc=0.95, Test loss=1.57
# Optimizer: momentum, Activation: leaky_relu, Learning Rate: 0.001
# Epoch 1: 5.29s, train acc=0.50, train loss=2.18, validation acc=0.49, validation loss=2.18
# Epoch 2: 11.09s, train acc=0.68, train loss=2.07, validation acc=0.67, validation loss=2.08
# Epoch 3: 15.33s, train acc=0.75, train loss=1.99, validation acc=0.75, validation loss=1.99
# Epoch 4: 21.20s, train acc=0.79, train loss=1.93, validation acc=0.78, validation loss=1.93
# Epoch 5: 26.17s, train acc=0.82, train loss=1.88, validation acc=0.80, validation loss=1.88
# Epoch 6: 30.59s, train acc=0.83, train loss=1.84, validation acc=0.82, validation loss=1.85
# Epoch 7: 37.72s, train acc=0.84, train loss=1.82, validation acc=0.83, validation loss=1.82
# Epoch 8: 42.06s, train acc=0.85, train loss=1.80, validation acc=0.84, validation loss=1.80
# Epoch 9: 46.47s, train acc=0.86, train loss=1.78, validation acc=0.85, validation loss=1.79
# Epoch 10: 53.67s, train acc=0.87, train loss=1.76, validation acc=0.86, validation loss=1.77
# Epoch 11: 57.97s, train acc=0.87, train loss=1.75, validation acc=0.86, validation loss=1.76
# Epoch 12: 62.48s, train acc=0.88, train loss=1.74, validation acc=0.87, validation loss=1.75
# Epoch 13: 69.64s, train acc=0.88, train loss=1.73, validation acc=0.87, validation loss=1.74
# Epoch 14: 74.13s, train acc=0.89, train loss=1.72, validation acc=0.88, validation loss=1.74
# Epoch 15: 79.58s, train acc=0.89, train loss=1.72, validation acc=0.88, validation loss=1.73
# Epoch 16: 84.82s, train acc=0.89, train loss=1.71, validation acc=0.88, validation loss=1.72
# Epoch 17: 89.22s, train acc=0.89, train loss=1.71, validation acc=0.88, validation loss=1.72
# Epoch 18: 95.47s, train acc=0.90, train loss=1.70, validation acc=0.88, validation loss=1.71
# Epoch 19: 99.91s, train acc=0.90, train loss=1.70, validation acc=0.89, validation loss=1.71
# Epoch 20: 104.28s, train acc=0.90, train loss=1.69, validation acc=0.89, validation loss=1.70
#
# Test acc=0.89, Test loss=1.70
# Optimizer: momentum, Activation: selu, Learning Rate: 0.01
# Epoch 1: 8.31s, train acc=0.85, train loss=1.83, validation acc=0.84, validation loss=1.84
# Epoch 2: 13.77s, train acc=0.88, train loss=1.80, validation acc=0.86, validation loss=1.80
# Epoch 3: 21.40s, train acc=0.89, train loss=1.77, validation acc=0.88, validation loss=1.77
# Epoch 4: 26.70s, train acc=0.90, train loss=1.74, validation acc=0.89, validation loss=1.75
# Epoch 5: 32.76s, train acc=0.91, train loss=1.71, validation acc=0.90, validation loss=1.72
# Epoch 6: 39.29s, train acc=0.92, train loss=1.69, validation acc=0.90, validation loss=1.70
# Epoch 7: 44.59s, train acc=0.92, train loss=1.68, validation acc=0.91, validation loss=1.69
# Epoch 8: 52.78s, train acc=0.92, train loss=1.67, validation acc=0.91, validation loss=1.68
# Epoch 9: 58.23s, train acc=0.93, train loss=1.66, validation acc=0.91, validation loss=1.67
# Epoch 10: 66.12s, train acc=0.93, train loss=1.65, validation acc=0.92, validation loss=1.66
# Epoch 11: 71.40s, train acc=0.93, train loss=1.64, validation acc=0.92, validation loss=1.65
# Epoch 12: 77.81s, train acc=0.93, train loss=1.64, validation acc=0.92, validation loss=1.65
# Epoch 13: 84.04s, train acc=0.93, train loss=1.64, validation acc=0.92, validation loss=1.65
# Epoch 14: 89.28s, train acc=0.94, train loss=1.63, validation acc=0.92, validation loss=1.64
# Epoch 15: 97.60s, train acc=0.94, train loss=1.62, validation acc=0.93, validation loss=1.64
# Epoch 16: 102.99s, train acc=0.94, train loss=1.62, validation acc=0.93, validation loss=1.63
# Epoch 17: 110.66s, train acc=0.94, train loss=1.62, validation acc=0.93, validation loss=1.63
# Epoch 18: 115.86s, train acc=0.94, train loss=1.61, validation acc=0.93, validation loss=1.63
# Epoch 19: 121.59s, train acc=0.94, train loss=1.61, validation acc=0.93, validation loss=1.62
# Epoch 20: 128.32s, train acc=0.94, train loss=1.61, validation acc=0.93, validation loss=1.62
#
# Test acc=0.93, Test loss=1.62
# Optimizer: momentum, Activation: selu, Learning Rate: 0.001
# Epoch 1: 5.19s, train acc=0.70, train loss=1.93, validation acc=0.69, validation loss=1.93
# Epoch 2: 13.15s, train acc=0.78, train loss=1.89, validation acc=0.76, validation loss=1.90
# Epoch 3: 18.13s, train acc=0.81, train loss=1.87, validation acc=0.79, validation loss=1.88
# Epoch 4: 25.19s, train acc=0.82, train loss=1.86, validation acc=0.80, validation loss=1.87
# Epoch 5: 30.53s, train acc=0.83, train loss=1.85, validation acc=0.82, validation loss=1.86
# Epoch 6: 35.81s, train acc=0.84, train loss=1.84, validation acc=0.82, validation loss=1.85
# Epoch 7: 43.55s, train acc=0.85, train loss=1.83, validation acc=0.83, validation loss=1.84
# Epoch 8: 48.73s, train acc=0.85, train loss=1.83, validation acc=0.84, validation loss=1.84
# Epoch 9: 56.35s, train acc=0.86, train loss=1.82, validation acc=0.84, validation loss=1.83
# Epoch 10: 61.27s, train acc=0.86, train loss=1.82, validation acc=0.84, validation loss=1.82
# Epoch 11: 67.07s, train acc=0.87, train loss=1.81, validation acc=0.85, validation loss=1.82
# Epoch 12: 74.08s, train acc=0.87, train loss=1.81, validation acc=0.85, validation loss=1.82
# Epoch 13: 79.31s, train acc=0.87, train loss=1.80, validation acc=0.86, validation loss=1.81
# Epoch 14: 87.34s, train acc=0.88, train loss=1.80, validation acc=0.86, validation loss=1.81
# Epoch 15: 92.41s, train acc=0.88, train loss=1.79, validation acc=0.86, validation loss=1.80
# Epoch 16: 99.36s, train acc=0.88, train loss=1.79, validation acc=0.86, validation loss=1.80
# Epoch 17: 104.75s, train acc=0.88, train loss=1.78, validation acc=0.87, validation loss=1.79
# Epoch 18: 110.94s, train acc=0.88, train loss=1.78, validation acc=0.87, validation loss=1.79
# Epoch 19: 117.39s, train acc=0.89, train loss=1.78, validation acc=0.87, validation loss=1.79
# Epoch 20: 122.40s, train acc=0.89, train loss=1.77, validation acc=0.87, validation loss=1.78
#
# Test acc=0.87, Test loss=1.78
# Optimizer: momentum, Activation: elu, Learning Rate: 0.01
# Epoch 1: 7.76s, train acc=0.85, train loss=1.84, validation acc=0.83, validation loss=1.85
# Epoch 2: 12.82s, train acc=0.87, train loss=1.81, validation acc=0.85, validation loss=1.81
# Epoch 3: 19.95s, train acc=0.89, train loss=1.78, validation acc=0.87, validation loss=1.78
# Epoch 4: 25.17s, train acc=0.90, train loss=1.75, validation acc=0.89, validation loss=1.76
# Epoch 5: 30.22s, train acc=0.91, train loss=1.73, validation acc=0.90, validation loss=1.74
# Epoch 6: 38.04s, train acc=0.91, train loss=1.71, validation acc=0.90, validation loss=1.72
# Epoch 7: 43.22s, train acc=0.92, train loss=1.69, validation acc=0.90, validation loss=1.70
# Epoch 8: 50.54s, train acc=0.92, train loss=1.69, validation acc=0.91, validation loss=1.69
# Epoch 9: 55.69s, train acc=0.92, train loss=1.67, validation acc=0.91, validation loss=1.68
# Epoch 10: 61.39s, train acc=0.92, train loss=1.66, validation acc=0.91, validation loss=1.67
# Epoch 11: 67.99s, train acc=0.93, train loss=1.66, validation acc=0.92, validation loss=1.67
# Epoch 12: 72.98s, train acc=0.93, train loss=1.65, validation acc=0.92, validation loss=1.66
# Epoch 13: 80.70s, train acc=0.93, train loss=1.65, validation acc=0.92, validation loss=1.66
# Epoch 14: 85.72s, train acc=0.93, train loss=1.64, validation acc=0.92, validation loss=1.65
# Epoch 15: 91.92s, train acc=0.93, train loss=1.64, validation acc=0.93, validation loss=1.65
# Epoch 16: 97.94s, train acc=0.94, train loss=1.64, validation acc=0.93, validation loss=1.65
# Epoch 17: 103.09s, train acc=0.94, train loss=1.63, validation acc=0.93, validation loss=1.64
# Epoch 18: 111.20s, train acc=0.94, train loss=1.63, validation acc=0.93, validation loss=1.64
# Epoch 19: 116.38s, train acc=0.94, train loss=1.63, validation acc=0.93, validation loss=1.64
# Epoch 20: 123.83s, train acc=0.94, train loss=1.62, validation acc=0.93, validation loss=1.63
#
# Test acc=0.93, Test loss=1.63
# Optimizer: momentum, Activation: elu, Learning Rate: 0.001
# Epoch 1: 5.45s, train acc=0.67, train loss=2.01, validation acc=0.65, validation loss=2.02
# Epoch 2: 11.54s, train acc=0.75, train loss=1.95, validation acc=0.74, validation loss=1.95
# Epoch 3: 17.86s, train acc=0.79, train loss=1.91, validation acc=0.78, validation loss=1.92
# Epoch 4: 22.99s, train acc=0.81, train loss=1.89, validation acc=0.80, validation loss=1.90
# Epoch 5: 31.02s, train acc=0.82, train loss=1.88, validation acc=0.81, validation loss=1.88
# Epoch 6: 36.36s, train acc=0.83, train loss=1.87, validation acc=0.82, validation loss=1.87
# Epoch 7: 43.49s, train acc=0.84, train loss=1.86, validation acc=0.82, validation loss=1.86
# Epoch 8: 48.66s, train acc=0.84, train loss=1.85, validation acc=0.83, validation loss=1.86
# Epoch 9: 54.48s, train acc=0.85, train loss=1.84, validation acc=0.83, validation loss=1.85
# Epoch 10: 61.50s, train acc=0.85, train loss=1.84, validation acc=0.84, validation loss=1.85
# Epoch 11: 66.90s, train acc=0.85, train loss=1.83, validation acc=0.84, validation loss=1.84
# Epoch 12: 74.79s, train acc=0.86, train loss=1.83, validation acc=0.84, validation loss=1.84
# Epoch 13: 79.90s, train acc=0.86, train loss=1.82, validation acc=0.84, validation loss=1.83
# Epoch 14: 87.16s, train acc=0.86, train loss=1.82, validation acc=0.84, validation loss=1.83
# Epoch 15: 92.28s, train acc=0.86, train loss=1.82, validation acc=0.85, validation loss=1.82
# Epoch 16: 98.03s, train acc=0.86, train loss=1.81, validation acc=0.85, validation loss=1.82
# Epoch 17: 104.97s, train acc=0.87, train loss=1.81, validation acc=0.85, validation loss=1.82
# Epoch 18: 110.26s, train acc=0.87, train loss=1.81, validation acc=0.85, validation loss=1.82
# Epoch 19: 118.22s, train acc=0.87, train loss=1.80, validation acc=0.85, validation loss=1.81
# Epoch 20: 123.52s, train acc=0.87, train loss=1.80, validation acc=0.86, validation loss=1.81
#
# Test acc=0.86, Test loss=1.81
# Optimizer: sgd, Activation: relu, Learning Rate: 0.01
# Epoch 1: 4.85s, train acc=0.88, train loss=1.77, validation acc=0.87, validation loss=1.77
# Epoch 2: 9.91s, train acc=0.91, train loss=1.69, validation acc=0.90, validation loss=1.69
# Epoch 3: 13.70s, train acc=0.92, train loss=1.65, validation acc=0.91, validation loss=1.66
# Epoch 4: 17.67s, train acc=0.93, train loss=1.63, validation acc=0.92, validation loss=1.64
# Epoch 5: 24.11s, train acc=0.94, train loss=1.62, validation acc=0.92, validation loss=1.63
# Epoch 6: 27.96s, train acc=0.94, train loss=1.61, validation acc=0.93, validation loss=1.62
# Epoch 7: 31.78s, train acc=0.94, train loss=1.60, validation acc=0.93, validation loss=1.61
# Epoch 8: 38.48s, train acc=0.95, train loss=1.60, validation acc=0.94, validation loss=1.61
# Epoch 9: 42.43s, train acc=0.95, train loss=1.59, validation acc=0.94, validation loss=1.60
# Epoch 10: 46.26s, train acc=0.95, train loss=1.58, validation acc=0.94, validation loss=1.59
# Epoch 11: 52.43s, train acc=0.95, train loss=1.58, validation acc=0.94, validation loss=1.59
# Epoch 12: 56.20s, train acc=0.96, train loss=1.58, validation acc=0.95, validation loss=1.59
# Epoch 13: 59.95s, train acc=0.96, train loss=1.57, validation acc=0.95, validation loss=1.58
# ...
# Epoch 18: 101.83s, train acc=0.39, train loss=2.29, validation acc=0.39, validation loss=2.29
# Epoch 19: 108.34s, train acc=0.42, train loss=2.29, validation acc=0.41, validation loss=2.29
# Epoch 20: 112.71s, train acc=0.40, train loss=2.29, validation acc=0.40, validation loss=2.29
#
# Test acc=0.40, Test loss=2.29
# Optimizer: sgd, Activation: tanh, Learning Rate: 0.01
# Epoch 1: 6.62s, train acc=0.84, train loss=1.86, validation acc=0.83, validation loss=1.86
# Epoch 2: 14.66s, train acc=0.87, train loss=1.81, validation acc=0.85, validation loss=1.82
# Epoch 3: 21.53s, train acc=0.88, train loss=1.78, validation acc=0.87, validation loss=1.79
# Epoch 4: 29.24s, train acc=0.89, train loss=1.75, validation acc=0.88, validation loss=1.76
# Epoch 5: 36.21s, train acc=0.90, train loss=1.72, validation acc=0.89, validation loss=1.73
# Epoch 6: 43.86s, train acc=0.90, train loss=1.70, validation acc=0.90, validation loss=1.71
# Epoch 7: 50.73s, train acc=0.91, train loss=1.68, validation acc=0.90, validation loss=1.69
# Epoch 8: 58.34s, train acc=0.92, train loss=1.67, validation acc=0.91, validation loss=1.68
# Epoch 9: 65.48s, train acc=0.92, train loss=1.66, validation acc=0.91, validation loss=1.67
# Epoch 10: 73.14s, train acc=0.92, train loss=1.65, validation acc=0.91, validation loss=1.66
# Epoch 11: 80.15s, train acc=0.92, train loss=1.64, validation acc=0.91, validation loss=1.65
# Epoch 12: 87.49s, train acc=0.93, train loss=1.63, validation acc=0.92, validation loss=1.64
# Epoch 13: 94.49s, train acc=0.93, train loss=1.63, validation acc=0.92, validation loss=1.64
# Epoch 14: 102.02s, train acc=0.93, train loss=1.62, validation acc=0.92, validation loss=1.63
# Epoch 15: 109.22s, train acc=0.93, train loss=1.62, validation acc=0.92, validation loss=1.63
# Epoch 16: 116.10s, train acc=0.93, train loss=1.61, validation acc=0.92, validation loss=1.62
# Epoch 17: 123.53s, train acc=0.94, train loss=1.61, validation acc=0.92, validation loss=1.62
# Epoch 18: 130.25s, train acc=0.94, train loss=1.60, validation acc=0.92, validation loss=1.61
# Epoch 19: 137.98s, train acc=0.94, train loss=1.60, validation acc=0.93, validation loss=1.61
# Epoch 20: 144.83s, train acc=0.94, train loss=1.60, validation acc=0.93, validation loss=1.61
#
# Test acc=0.93, Test loss=1.61
# Optimizer: sgd, Activation: tanh, Learning Rate: 0.001
# Epoch 1: 7.99s, train acc=0.68, train loss=2.02, validation acc=0.66, validation loss=2.02
# Epoch 2: 14.52s, train acc=0.76, train loss=1.95, validation acc=0.75, validation loss=1.96
# Epoch 3: 23.52s, train acc=0.79, train loss=1.92, validation acc=0.78, validation loss=1.93
# Epoch 4: 29.92s, train acc=0.81, train loss=1.90, validation acc=0.79, validation loss=1.91
# Epoch 5: 38.98s, train acc=0.82, train loss=1.89, validation acc=0.81, validation loss=1.90
# Epoch 6: 45.42s, train acc=0.83, train loss=1.88, validation acc=0.81, validation loss=1.89
# Epoch 7: 54.81s, train acc=0.83, train loss=1.87, validation acc=0.82, validation loss=1.88
# Epoch 8: 61.26s, train acc=0.84, train loss=1.87, validation acc=0.82, validation loss=1.87
# Epoch 9: 70.47s, train acc=0.84, train loss=1.86, validation acc=0.83, validation loss=1.87
# Epoch 10: 76.93s, train acc=0.84, train loss=1.86, validation acc=0.83, validation loss=1.86
# Epoch 11: 86.37s, train acc=0.85, train loss=1.85, validation acc=0.83, validation loss=1.86
# Epoch 12: 92.70s, train acc=0.85, train loss=1.85, validation acc=0.84, validation loss=1.85
# Epoch 13: 101.82s, train acc=0.85, train loss=1.84, validation acc=0.84, validation loss=1.85
# Epoch 14: 108.39s, train acc=0.85, train loss=1.84, validation acc=0.84, validation loss=1.85
# Epoch 15: 117.20s, train acc=0.86, train loss=1.83, validation acc=0.84, validation loss=1.84
# Epoch 16: 123.95s, train acc=0.86, train loss=1.83, validation acc=0.84, validation loss=1.84
# Epoch 17: 134.66s, train acc=0.86, train loss=1.83, validation acc=0.85, validation loss=1.83
# Epoch 18: 143.56s, train acc=0.86, train loss=1.82, validation acc=0.85, validation loss=1.83
# Epoch 19: 150.09s, train acc=0.87, train loss=1.82, validation acc=0.85, validation loss=1.83
# Epoch 20: 159.05s, train acc=0.87, train loss=1.81, validation acc=0.85, validation loss=1.82
#
# Test acc=0.85, Test loss=1.82
# Optimizer: sgd, Activation: leaky_relu, Learning Rate: 0.01
# Epoch 1: 3.87s, train acc=0.87, train loss=1.76, validation acc=0.86, validation loss=1.77
# Epoch 2: 7.69s, train acc=0.90, train loss=1.69, validation acc=0.89, validation loss=1.70
# Epoch 3: 14.41s, train acc=0.92, train loss=1.66, validation acc=0.90, validation loss=1.67
# Epoch 4: 18.20s, train acc=0.92, train loss=1.64, validation acc=0.91, validation loss=1.65
# Epoch 5: 22.03s, train acc=0.93, train loss=1.64, validation acc=0.92, validation loss=1.65
# Epoch 6: 28.22s, train acc=0.94, train loss=1.63, validation acc=0.92, validation loss=1.64
# Epoch 7: 32.12s, train acc=0.94, train loss=1.61, validation acc=0.93, validation loss=1.62
# Epoch 8: 35.88s, train acc=0.94, train loss=1.60, validation acc=0.93, validation loss=1.62
# Epoch 9: 41.58s, train acc=0.95, train loss=1.60, validation acc=0.93, validation loss=1.61
# Epoch 10: 45.69s, train acc=0.95, train loss=1.59, validation acc=0.94, validation loss=1.61
# Epoch 11: 49.63s, train acc=0.95, train loss=1.59, validation acc=0.94, validation loss=1.60
# Epoch 12: 54.20s, train acc=0.95, train loss=1.58, validation acc=0.94, validation loss=1.60
# Epoch 13: 59.43s, train acc=0.96, train loss=1.58, validation acc=0.94, validation loss=1.59
# Epoch 14: 63.26s, train acc=0.96, train loss=1.58, validation acc=0.94, validation loss=1.59
# Epoch 15: 66.88s, train acc=0.96, train loss=1.57, validation acc=0.95, validation loss=1.59
# Epoch 16: 73.70s, train acc=0.96, train loss=1.57, validation acc=0.95, validation loss=1.58
# Epoch 17: 77.50s, train acc=0.96, train loss=1.57, validation acc=0.95, validation loss=1.58
# Epoch 18: 81.37s, train acc=0.96, train loss=1.56, validation acc=0.95, validation loss=1.58
# Epoch 19: 87.98s, train acc=0.96, train loss=1.56, validation acc=0.95, validation loss=1.57
# Epoch 20: 91.86s, train acc=0.97, train loss=1.56, validation acc=0.95, validation loss=1.57
#
# Test acc=0.95, Test loss=1.57
# Optimizer: sgd, Activation: leaky_relu, Learning Rate: 0.001
# Epoch 1: 3.92s, train acc=0.47, train loss=2.20, validation acc=0.47, validation loss=2.20
# Epoch 2: 10.50s, train acc=0.65, train loss=2.11, validation acc=0.64, validation loss=2.11
# Epoch 3: 14.38s, train acc=0.73, train loss=2.03, validation acc=0.72, validation loss=2.03
# Epoch 4: 18.30s, train acc=0.77, train loss=1.96, validation acc=0.77, validation loss=1.97
# Epoch 5: 24.68s, train acc=0.80, train loss=1.91, validation acc=0.79, validation loss=1.91
# Epoch 6: 28.54s, train acc=0.82, train loss=1.86, validation acc=0.81, validation loss=1.87
# Epoch 7: 32.34s, train acc=0.84, train loss=1.83, validation acc=0.83, validation loss=1.84
# Epoch 8: 38.31s, train acc=0.85, train loss=1.81, validation acc=0.84, validation loss=1.81
# Epoch 9: 42.05s, train acc=0.86, train loss=1.79, validation acc=0.85, validation loss=1.80
# Epoch 10: 45.76s, train acc=0.87, train loss=1.77, validation acc=0.85, validation loss=1.78
# Epoch 11: 50.40s, train acc=0.87, train loss=1.76, validation acc=0.86, validation loss=1.77
# Epoch 12: 55.79s, train acc=0.88, train loss=1.75, validation acc=0.87, validation loss=1.76
# Epoch 13: 59.59s, train acc=0.88, train loss=1.74, validation acc=0.87, validation loss=1.75
# Epoch 14: 63.49s, train acc=0.89, train loss=1.73, validation acc=0.87, validation loss=1.74
# Epoch 15: 70.22s, train acc=0.89, train loss=1.72, validation acc=0.88, validation loss=1.73
# Epoch 16: 73.99s, train acc=0.89, train loss=1.72, validation acc=0.88, validation loss=1.73
# Epoch 17: 77.63s, train acc=0.90, train loss=1.71, validation acc=0.88, validation loss=1.72
# Epoch 18: 84.10s, train acc=0.90, train loss=1.70, validation acc=0.89, validation loss=1.71
# Epoch 19: 87.93s, train acc=0.90, train loss=1.70, validation acc=0.89, validation loss=1.71
# Epoch 20: 91.69s, train acc=0.90, train loss=1.69, validation acc=0.89, validation loss=1.70
#
# Test acc=0.89, Test loss=1.70
# Optimizer: sgd, Activation: selu, Learning Rate: 0.01
# Epoch 1: 7.14s, train acc=0.86, train loss=1.81, validation acc=0.85, validation loss=1.82
# Epoch 2: 11.83s, train acc=0.88, train loss=1.78, validation acc=0.87, validation loss=1.78
# Epoch 3: 16.89s, train acc=0.90, train loss=1.74, validation acc=0.88, validation loss=1.75
# Epoch 4: 23.79s, train acc=0.90, train loss=1.71, validation acc=0.89, validation loss=1.72
# Epoch 5: 28.68s, train acc=0.91, train loss=1.69, validation acc=0.90, validation loss=1.70
# Epoch 6: 35.70s, train acc=0.92, train loss=1.68, validation acc=0.91, validation loss=1.69
# Epoch 7: 40.51s, train acc=0.92, train loss=1.67, validation acc=0.91, validation loss=1.68
# Epoch 8: 45.34s, train acc=0.93, train loss=1.66, validation acc=0.91, validation loss=1.67
# Epoch 9: 53.11s, train acc=0.93, train loss=1.65, validation acc=0.92, validation loss=1.66
# Epoch 10: 57.88s, train acc=0.93, train loss=1.65, validation acc=0.92, validation loss=1.66
# Epoch 11: 63.96s, train acc=0.93, train loss=1.64, validation acc=0.92, validation loss=1.65
# Epoch 12: 69.07s, train acc=0.93, train loss=1.63, validation acc=0.92, validation loss=1.64
# Epoch 13: 73.78s, train acc=0.94, train loss=1.63, validation acc=0.92, validation loss=1.64
# Epoch 14: 83.22s, train acc=0.94, train loss=1.63, validation acc=0.92, validation loss=1.64
# Epoch 15: 87.99s, train acc=0.93, train loss=1.62, validation acc=0.92, validation loss=1.63
# Epoch 16: 92.95s, train acc=0.94, train loss=1.61, validation acc=0.92, validation loss=1.63
# Epoch 17: 100.09s, train acc=0.94, train loss=1.62, validation acc=0.93, validation loss=1.63
# Epoch 18: 104.83s, train acc=0.94, train loss=1.61, validation acc=0.92, validation loss=1.62
# Epoch 19: 111.36s, train acc=0.94, train loss=1.61, validation acc=0.93, validation loss=1.62
# Epoch 20: 116.29s, train acc=0.94, train loss=1.60, validation acc=0.93, validation loss=1.62
#
# Test acc=0.93, Test loss=1.62
# Optimizer: sgd, Activation: selu, Learning Rate: 0.001
# Epoch 1: 4.78s, train acc=0.70, train loss=1.94, validation acc=0.69, validation loss=1.95
# Epoch 2: 12.44s, train acc=0.77, train loss=1.90, validation acc=0.76, validation loss=1.91
# Epoch 3: 17.36s, train acc=0.80, train loss=1.88, validation acc=0.78, validation loss=1.89
# Epoch 4: 23.19s, train acc=0.82, train loss=1.87, validation acc=0.80, validation loss=1.88
# Epoch 5: 29.07s, train acc=0.83, train loss=1.86, validation acc=0.81, validation loss=1.87
# Epoch 6: 33.95s, train acc=0.84, train loss=1.85, validation acc=0.82, validation loss=1.86
# Epoch 7: 41.71s, train acc=0.84, train loss=1.84, validation acc=0.82, validation loss=1.85
# Epoch 8: 46.50s, train acc=0.85, train loss=1.84, validation acc=0.83, validation loss=1.85
# Epoch 9: 51.69s, train acc=0.85, train loss=1.83, validation acc=0.83, validation loss=1.84
# Epoch 10: 58.45s, train acc=0.86, train loss=1.83, validation acc=0.84, validation loss=1.84
# Epoch 11: 63.13s, train acc=0.86, train loss=1.82, validation acc=0.84, validation loss=1.83
# Epoch 12: 70.05s, train acc=0.86, train loss=1.82, validation acc=0.84, validation loss=1.83
# Epoch 13: 74.76s, train acc=0.87, train loss=1.81, validation acc=0.85, validation loss=1.82
# Epoch 14: 79.44s, train acc=0.87, train loss=1.81, validation acc=0.85, validation loss=1.82
# Epoch 15: 86.94s, train acc=0.87, train loss=1.81, validation acc=0.85, validation loss=1.82
# Epoch 16: 91.50s, train acc=0.87, train loss=1.80, validation acc=0.86, validation loss=1.81
# Epoch 17: 96.77s, train acc=0.87, train loss=1.80, validation acc=0.86, validation loss=1.81
# Epoch 18: 103.19s, train acc=0.88, train loss=1.80, validation acc=0.86, validation loss=1.81
# Epoch 19: 107.89s, train acc=0.88, train loss=1.79, validation acc=0.86, validation loss=1.80
# Epoch 20: 114.83s, train acc=0.88, train loss=1.79, validation acc=0.87, validation loss=1.80
#
# Test acc=0.87, Test loss=1.80
# Optimizer: sgd, Activation: elu, Learning Rate: 0.01
# Epoch 1: 4.48s, train acc=0.85, train loss=1.84, validation acc=0.83, validation loss=1.85
# Epoch 2: 9.00s, train acc=0.87, train loss=1.81, validation acc=0.86, validation loss=1.81
# Epoch 3: 16.38s, train acc=0.88, train loss=1.78, validation acc=0.87, validation loss=1.78
# Epoch 4: 20.85s, train acc=0.89, train loss=1.75, validation acc=0.88, validation loss=1.76
# Epoch 5: 25.60s, train acc=0.90, train loss=1.73, validation acc=0.89, validation loss=1.74
# Epoch 6: 32.27s, train acc=0.91, train loss=1.71, validation acc=0.89, validation loss=1.72
# Epoch 7: 36.75s, train acc=0.92, train loss=1.69, validation acc=0.90, validation loss=1.70
# Epoch 8: 42.67s, train acc=0.92, train loss=1.68, validation acc=0.90, validation loss=1.69
# Epoch 9: 47.88s, train acc=0.92, train loss=1.67, validation acc=0.91, validation loss=1.68
# Epoch 10: 52.48s, train acc=0.93, train loss=1.66, validation acc=0.91, validation loss=1.67
# Epoch 11: 59.38s, train acc=0.93, train loss=1.65, validation acc=0.91, validation loss=1.66
# Epoch 12: 63.77s, train acc=0.93, train loss=1.65, validation acc=0.92, validation loss=1.66
# Epoch 13: 68.42s, train acc=0.93, train loss=1.64, validation acc=0.92, validation loss=1.66
# Epoch 14: 75.85s, train acc=0.94, train loss=1.64, validation acc=0.92, validation loss=1.65
# Epoch 15: 80.54s, train acc=0.94, train loss=1.64, validation acc=0.93, validation loss=1.65
# Epoch 16: 85.92s, train acc=0.94, train loss=1.63, validation acc=0.93, validation loss=1.64
# Epoch 17: 91.73s, train acc=0.94, train loss=1.63, validation acc=0.93, validation loss=1.64
# Epoch 18: 96.35s, train acc=0.94, train loss=1.63, validation acc=0.93, validation loss=1.64
# Epoch 19: 102.84s, train acc=0.94, train loss=1.62, validation acc=0.93, validation loss=1.63
# Epoch 20: 107.64s, train acc=0.94, train loss=1.62, validation acc=0.93, validation loss=1.63
#
# Test acc=0.93, Test loss=1.63
# Optimizer: sgd, Activation: elu, Learning Rate: 0.001
# Epoch 1: 4.70s, train acc=0.67, train loss=2.00, validation acc=0.66, validation loss=2.01
# Epoch 2: 12.19s, train acc=0.76, train loss=1.94, validation acc=0.75, validation loss=1.94
# Epoch 3: 16.72s, train acc=0.80, train loss=1.90, validation acc=0.78, validation loss=1.91
# Epoch 4: 21.97s, train acc=0.82, train loss=1.88, validation acc=0.80, validation loss=1.89
# Epoch 5: 31.07s, train acc=0.83, train loss=1.87, validation acc=0.81, validation loss=1.88
# Epoch 6: 35.65s, train acc=0.84, train loss=1.86, validation acc=0.82, validation loss=1.87
# Epoch 7: 42.89s, train acc=0.84, train loss=1.85, validation acc=0.82, validation loss=1.86
# Epoch 8: 47.55s, train acc=0.85, train loss=1.84, validation acc=0.83, validation loss=1.85
# Epoch 9: 52.25s, train acc=0.85, train loss=1.84, validation acc=0.83, validation loss=1.85
# Epoch 10: 59.32s, train acc=0.85, train loss=1.83, validation acc=0.83, validation loss=1.84
# Epoch 11: 64.02s, train acc=0.86, train loss=1.83, validation acc=0.84, validation loss=1.84
# Epoch 12: 70.53s, train acc=0.86, train loss=1.82, validation acc=0.84, validation loss=1.83
# Epoch 13: 75.18s, train acc=0.86, train loss=1.82, validation acc=0.84, validation loss=1.83
# Epoch 14: 80.06s, train acc=0.86, train loss=1.82, validation acc=0.85, validation loss=1.82
# Epoch 15: 87.63s, train acc=0.87, train loss=1.81, validation acc=0.85, validation loss=1.82
# Epoch 16: 92.26s, train acc=0.87, train loss=1.81, validation acc=0.85, validation loss=1.82
# Epoch 17: 97.94s, train acc=0.87, train loss=1.81, validation acc=0.85, validation loss=1.81
# Epoch 18: 103.46s, train acc=0.87, train loss=1.80, validation acc=0.85, validation loss=1.81
# Epoch 19: 108.23s, train acc=0.87, train loss=1.80, validation acc=0.86, validation loss=1.81
# Epoch 20: 115.45s, train acc=0.87, train loss=1.80, validation acc=0.86, validation loss=1.81
#
# Test acc=0.86, Test loss=1.81
# Best accuracy: 0.9789, Best optimizer: adam, Best activation: leaky_relu, Best learning rate: 0.001

# %% [markdown]
# # MLP as function Approximator
# We know that a MLP with one hidden layer could  approximate any smooth function! <br> Here you will manually fit a sine function using ReLU activation. <br>You need to set the correct weights on ReLUs so the linear combination approximates the desired function.

# %%
def relu_approximation(input_data, target_labels):
    """
    Args:
      input_data: torch.tensor
        Input training data
      target_labels: torch.tensor
        Ground truth labels for training data

    Returns:
      activation_map: torch.tensor
        ReLU activations computed across the x-axis
      predicted_labels: torch.tensor
        Estimated labels or class predictions
        Derived from weighted sum of ReLU activations along the x-axis
      x_points: torch.tensor
        Points along the x-axis
    """
    ############################################################
    # Number of ReLU units
    num_relus = input_data.shape[0] - 1
    # Generate dense x-axis points for interpolation
    x_points = torch.linspace(torch.min(input_data), torch.max(input_data), 1000)

    # Compute bias for ReLU units
    biases = torch.linspace(torch.min(input_data), torch.max(input_data), num_relus+1)[:num_relus]

    # Initialize activation map to store ReLU activations
    activation_map = torch.zeros(num_relus, x_points.shape[0])

    for relu_idx in range(num_relus):
        activation_map[relu_idx, :] = torch.relu(x_points - biases[relu_idx])
    ## WEIGHTED SUM OF RELUS

    relu_weights = torch.zeros(num_relus)
    previous_slope = 0
    for j in range(num_relus):
        slop = (target_labels[j+1] - target_labels[j]) / (input_data[j+1] - input_data[j])
        relu_weights[j] = slop - previous_slope
        previous_slope = slop
    # Compute predicted labels as weighted sum of ReLU activations
    predicted_labels = relu_weights @ activation_map
    ############################################################

    return predicted_labels, activation_map, x_points


# Generate synthetic training data using sine function
num_samples = 10
input_data = torch.linspace(0, 2 * np.pi, num_samples).view(-1, 1)
target_labels = torch.sin(input_data)

predicted_output, activation_map, x_points = relu_approximation(input_data, target_labels)
plot_function_apx(x_points, activation_map, predicted_output)

# %% [markdown]
# # Depth vs. Width
# Here we wanna see the effect of width vs. depth on a classification task.First you are going to implement MLP again; But with 2 differences: <br>
#
# 1.   It is general purpose (i.e. works for desired depth and activation functions)
# 2.   You will implement it using pytorch

# %%
class MLP_pytorch(nn.Module):
  """
  Simulate MLP Network
  """

  def __init__(self, activation_fn, input_feature_num, hidden_unit_nums, output_feature_num):
    """
    Initialize MLP Network parameters

    Args:
      activation_fn: string
        Activation function
      input_feature_num: int
        Number of input features
      hidden_unit_nums: list
        Number of units per hidden layer. List of integers
      output_feature_num: int
        Number of output features

    Returns:
      Nothing
    """
    super(MLP_pytorch, self).__init__()
    self.input_feature_num = input_feature_num
    self.mlp = nn.Sequential()

    in_num = input_feature_num
    ############################################################
    for i in range(len(hidden_unit_nums)):
        self.mlp.add_module(f'Linear_{i}', nn.Linear(in_num, hidden_unit_nums[i]))
        in_num = hidden_unit_nums[i]
        self.mlp.add_module(f'Activation_{i}', getattr(nn, activation_fn)())

    out_layer = nn.Linear(in_num, output_feature_num) # final layer
    self.mlp.add_module('Output_Linear', out_layer)

    ############################################################

  def forward(self, x):
    """
    Simulate forward pass of MLP Network

    Args:
      x: torch.tensor
        Input data

    Returns:
      logits: Instance of MLP
        Forward pass of MLP
    """
    # Reshape inputs to (batch_size, input_feature_num)
    x = x.view(-1, self.input_feature_num)
    logits = self.mlp(x) # forward pass

    return logits

# %% [markdown]
# Now let's make a spiral dataset that follows this formula:
# \begin{equation}
# \begin{array}{c}
# X_{k}(t)=t\left(\begin{array}{c}
# \sin \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right) \\
# \cos \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right)
# \end{array}\right)
# \end{array}, \quad 0 \leq t \leq 1, \quad k=1, \ldots, K
# \end{equation}
#
# Run cell below to create the data and load it as tensors.

# %%
# @title Data Loader
K = 4
sigma = 0.4
N = 1000
t = torch.linspace(0, 1, N)
X = torch.zeros(K*N, 2)
y = torch.zeros(K*N)
for k in range(K):
  X[k*N:(k+1)*N, 0] = t*(torch.sin(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  X[k*N:(k+1)*N, 1] = t*(torch.cos(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  y[k*N:(k+1)*N] = k


X_test, y_test, X_train, y_train = shuffle_and_split_data(X, y, seed=SEED)

# DataLoader with random seed
batch_size = 128
g_seed = torch.Generator()
g_seed.manual_seed(SEED)

test_data = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_data, batch_size=batch_size,
                         shuffle=False, num_workers=0,
                         worker_init_fn=seed_worker,
                         generator=g_seed,
                         )

train_data = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_data,
                          batch_size=batch_size,
                          drop_last=True,
                          shuffle=True,
                          worker_init_fn=seed_worker,
                          generator=g_seed,
                          )

# %% [markdown]
# Now we will add more polynomial features to the dataset to make the first layer wider. Afterwards, train a single linear layer. We could use the same MLP network with no hidden layers (though it would not be called an MLP anymore!).
#
# Add polynomial terms up to $P=50$ which means that for every $x_1^n x_2^m$ term, $n+m\leq P$. Total number of polynomial features up to $P$ follows this formula:
#
# \begin{equation}
# \text{# of terms} = \frac{(P+1)(P+2)}{2}
# \end{equation}
#
# Also, we don't need the polynomial term with degree zero (which is the constatnt term) since `nn.Linear` layers have bias terms. Therefore we will have one fewer polynomial feature.

# %%
def polynomial_classifier(poly_degree, seed=0):
  """
  Helper function to run the polynomial classifier

  Args:
    poly_degree: int
      Degree of the polynomial
    seed: int
      A non-negative integer that defines the random state.

  Returns:
    num_features: int
      Number of features
  """

  def polynomial_features(poly_degree, X):
    """
    Function to define the number of polynomial features except the bias term

    Args:
      poly_degree: int
        Degree of the polynomial
      X: torch.tensor
        Input data

    Returns:
      num_features: int
        Number of features
      poly_X: torch.tensor
        Polynomial term
    """
    ############################################################
    num_features = (poly_degree + 1) * (poly_degree + 2) // 2 - 1
    poly_X = torch.zeros((X.shape[0], num_features))
    cnt = 0
    for i in range(0 , poly_degree+1) :
        for j in range(poly_degree+1) :
            if i+j==0 or i+j>poly_degree:
                continue
            poly_X[:, cnt] = X[:, 0] ** i * X[:, 1] ** j
            cnt+=1
    return poly_X, num_features
    ############################################################

  poly_X_test, num_features = polynomial_features(poly_degree, X_test)
  poly_X_train, _ = polynomial_features(poly_degree, X_train)

  batch_size = 128

  g_seed = torch.Generator()
  g_seed.manual_seed(seed)
  poly_test_data = TensorDataset(poly_X_test, y_test)
  poly_test_loader = DataLoader(poly_test_data,
                                batch_size=batch_size,
                                shuffle=False,
                                num_workers=1,
                                worker_init_fn=seed_worker,
                                generator=g_seed)

  poly_train_data = TensorDataset(poly_X_train, y_train)
  poly_train_loader = DataLoader(poly_train_data,
                                 batch_size=batch_size,
                                 shuffle=True,
                                 num_workers=1,
                                 worker_init_fn=seed_worker,
                                 generator=g_seed)

  # Defining a linear model using MLP class
  poly_net = MLP_pytorch('ReLU()', num_features, [], K)

  # Train and test
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(poly_net.parameters(), lr=1e-3)
  _, _ = train_test_classification(poly_net, criterion, optimizer,
                                   poly_train_loader, poly_test_loader,
                                   num_epochs=100)
  X_all = sample_grid()
  poly_X_all, _ = polynomial_features(poly_degree, X_all)
  y_pred = poly_net(poly_X_all)

  # Plot
  plot_decision_map(X_all.cpu(), y_pred.cpu(), X_test.cpu(), y_test.cpu())
  plt.show()

  return num_features

# %% [markdown]
# ### Train the network. How does it generalize?

# %%
seed_setter(seed=SEED)
max_poly_deg = 50
num_features = polynomial_classifier(max_poly_deg)
print(f'Number of features: {num_features}')
# Out:
# Random seed 2024 has been set.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Accuracy on the 3200 training samples: 70.44
# Accuracy on the 800 testing samples: 70.25
# Number of features: 1325

# %% [markdown]
# Now create another instance of `MLP_pytorch` class having a hidden layer of 128 neurons and train it. Compare the result with the wide network. How does deeper model generalize? Is the decision boundaries ideal? Why?
#
#
# ANSWER :
# results of the deeper model are better than the wide model. The deeper model has a better generalization. The decision boundaries are not ideal because the model is not still deep enough to capture the complexity of the data and also there is not enough data.

# %%
############################################################
seed_setter(SEED)
num_features = 2
net2 = MLP_pytorch('ReLU', num_features, [128], K)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net2.parameters(), lr=1e-2)
num_epochs = 100

_, _ = train_test_classification(net2, criterion, optimizer, train_loader,
                                 test_loader, num_epochs=num_epochs,
                                 training_plot=True)

X_all = sample_grid()
y_pred = net2(X_all).cpu()
plot_decision_map(X_all, y_pred, X_test, y_test)

############################################################
# Out:
# Random seed 2024 has been set.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Accuracy on the 3200 training samples: 98.62
# Accuracy on the 800 testing samples: 98.25
